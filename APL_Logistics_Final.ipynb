# %% [markdown]
# ### Functions

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from keras.models import Sequential
from keras.layers import Dense, Dropout
import numpy as np
import pandas as pd
from sklearn import metrics
import pandas as pd
import numpy as np
import datetime
# !pip install joblib
import os
import numpy as np
import pandas as pd
import datetime
from sklearn.ensemble import RandomForestRegressor
import joblib
# !pip install streamlit

# RandomForestRegressor wrapper
def randomforest(max_depth, trees, criterion='squared_error', features='auto', warmstart=False):
    regr = RandomForestRegressor(n_estimators=trees,
                                 criterion=criterion,
                                 random_state=35,
                                 max_depth=max_depth,
                                 max_features=features,
                                 min_samples_leaf=10,
                                 warm_start=warmstart,
                                 n_jobs=-1,
                                 verbose=100)
    return regr

# GradientBoostingRegressor wrapper
def boost(depth, trees):
    boost = GradientBoostingRegressor(loss='squared_error', learning_rate=0.01,
                                      n_estimators=trees, max_depth=depth,
                                      criterion='squared_error', min_samples_leaf=10,
                                      random_state=35, max_features=2,
                                      verbose=100)
    return boost

# Neural network model for regression
def neural_net(df, neurons=10):
    model = Sequential()
    model.add(Dense(len(df.columns), input_dim=len(df.columns), kernel_initializer='normal', activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(neurons, kernel_initializer='normal', activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, kernel_initializer='normal'))
    model.compile(loss='mse', optimizer='adam', metrics=['mape', 'mae'])
    return model

# Print model performance metrics
def print_metrics(y_hat, y_test):
    output = pd.DataFrame({'MAE': [round(np.mean(abs(y_hat - y_test)), 2)],
                           'MAPE': [round(np.mean(abs(y_hat - y_test) / y_test), 4)],
                           'RMSE': [round(np.sqrt(np.mean((y_test - y_hat) ** 2)), 2)],
                           'R2': [round(metrics.r2_score(y_test, y_hat), 2)]})
    return output
# Out:
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (1.4.0)
# Collecting streamlit
#   Downloading streamlit-1.33.0-py2.py3-none-any.whl (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 47.3 MB/s eta 0:00:00
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.25.2)
# Requirement already satisfied: packaging<25,>=16.8 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.11.0)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 24.5 MB/s eta 0:00:00
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 85.3 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Collecting watchdog>=2.1.5 (from streamlit)
#   Downloading watchdog-4.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Installing collected packages: watchdog, smmap, pydeck, gitdb, gitpython, streamlit
# Successfully installed gitdb-4.0.11 gitpython-3.1.43 pydeck-0.8.1b0 smmap-5.0.1 streamlit-1.33.0 watchdog-4.0.0

# %% [markdown]
# ### Data Import

# %%
customer_clean = pd.read_csv('/content/drive/MyDrive/dataset_cleaned.csv')
chinese_holidays = pd.read_csv('/content/drive/MyDrive/chinese_holidays_complete.csv',
                                sep = ',', encoding= 'utf-8')

# %% [markdown]
# ### Data and Feature Engineering

# %%
date_columns = ['SCHEDULED_ETA', 'SCHEDULED_ETD', 'ACTUAL_DEPART_DATE', 'ACTUAL_ARRIVAL_DATE']

for column in date_columns:
    customer_clean[column] = pd.to_datetime(customer_clean[column].str.split(' ').str[0], format='%m/%d/%Y')

print(f'Sate columns in customer_clean datset converted into right format')

chinese_holidays['date'] = pd.to_datetime(chinese_holidays['date'])

customer_clean['holiday'] = np.where(customer_clean['SCHEDULED_ETD'].isin(chinese_holidays['date']), 1, 0)

print(f'Holiday column added to customer_clean dataset')

customer_clean['y_depart'] = (customer_clean['ACTUAL_ARRIVAL_DATE'] - customer_clean['ACTUAL_DEPART_DATE']).dt.days

print(f'Target column y_depart added to dataset')
# Out:
# Sate columns in customer_clean datset converted into right format
# Holiday column added to customer_clean dataset
# Target column y_depart added to dataset

# %%
def outlier_range(data):
  q1 = data.quantile(0.25)
  q3 = data.quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5 * iqr
  upper_bound = q3 + 1.5 * iqr
  return lower_bound, upper_bound

lower_bound, upper_bound = outlier_range(customer_clean['y_depart'])
print(f'The range of outliers for y_depart is between {lower_bound} and {upper_bound}')
# Out:
# The range of outliers for y_depart is between -10.0 and 70.0

# %%
# Calculating additional columns
customer_clean['route'] = (customer_clean['ACTUAL_ARRIVAL_DATE'] - customer_clean['ACTUAL_DEPART_DATE']).dt.days #transit time for shipment
customer_clean['delay_d'] = (customer_clean['ACTUAL_DEPART_DATE'] - customer_clean['SCHEDULED_ETD']).dt.days #delay in departure of shipment
customer_clean['delay_a'] = (customer_clean['ACTUAL_ARRIVAL_DATE'] - customer_clean['SCHEDULED_ETA']).dt.days #delay in arrival of shipment

# Filtering out rows with invalid dates or where 'route', 'delay_d', or 'delay_a' is negative
customer_clean = customer_clean[(customer_clean['ACTUAL_DEPART_DATE'].notna()) &
                                (customer_clean['route'] > 0) &
                                (customer_clean['delay_a'] >= 0) &
                                (customer_clean['delay_d'] >= 0)]

customer_clean['quarter'] = customer_clean['SCHEDULED_ETD'].dt.quarter # for seasonal trends
customer_clean['departure_day'] = customer_clean['ACTUAL_DEPART_DATE'].dt.day_name()

print(f'added additional columns for analysis')
#print(customer_clean)
# Out:
# added additional columns for analysis
# <ipython-input-6-d6ad498d46bb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_clean['quarter'] = customer_clean['SCHEDULED_ETD'].dt.quarter # for seasonal trends

# %% [markdown]
# ### Split Train - Test Dataset

# %%
duration = max(customer_clean['ACTUAL_ARRIVAL_DATE']) - datetime.timedelta(days=60)
train = customer_clean[customer_clean['ACTUAL_ARRIVAL_DATE'] < duration]
# print(train)

# # Double the observations  of last 2 months duration for better training
# duration_new = max(train['ACTUAL_ARRIVAL_DATE']) - datetime.timedelta(days=60)
# train = train.append(train[train['ACTUAL_ARRIVAL_DATE'] > duration_new])

print(train)

# Reset index for both dataframes to ensure they have unique identifiers
customer_clean_reset = customer_clean.reset_index()
train_reset = train.reset_index()

# Identify rows in customer_clean that are not in train
merged_df = pd.merge(customer_clean_reset, train_reset, on=list(customer_clean_reset.columns), how='left', indicator=True)
test = merged_df[merged_df['_merge'] == 'left_only']

# Drop the columns that were added during the merge, including the 'index' and '_merge' columns
test = test.drop(columns=['index', '_merge'])

# The test variable now contains rows that weren't included in the train dataset
print(test)
# Out:
#                     REFERENCE#  CUSTOMER SCHEDULED_ETA SCHEDULED_ETD  \
# 0         292613977MSKU1150398       250    2022-04-25    2022-03-02
# 1         292613977MRKU6377989       250    2022-04-25    2022-03-02
# 2         291435464MSKU0104736       250    2022-01-30    2022-01-23
# 4        SHA0744350TCNU7721431      3294    2022-03-26    2022-03-11
# 5         PNHA07475CSLU2003444      3294    2022-02-23    2022-01-16
# ...                        ...       ...           ...           ...
# 55965  143265913285EITU1528803       250    2022-08-13    2022-07-09
# 55966  143265913285GAOU6415936       250    2022-08-13    2022-07-09
# 55967    2691352960CSNU6328996      3294    2022-03-19    2022-02-25
# 55968     220207936MSKU9032513       250    2022-08-10    2022-07-18
# 55969     220207938MSKU9032513       250    2022-08-10    2022-07-18
#
#       ACTUAL_DEPART_DATE ACTUAL_ARRIVAL_DATE PORT_OF_LOAD LOAD_COUNTRY  \
# 0             2022-03-11          2022-04-25        CNSHA           CN
# 1             2022-03-11          2022-04-25        CNSHA           CN
# 2             2022-01-23          2022-02-01        GTPBR           GT
# 4             2022-03-12          2022-04-01        CNSHA           CN
# 5             2022-01-17          2022-03-05        KHPNH           KH
# ...                  ...                 ...          ...          ...
# 55965         2022-07-09          2022-08-20        CNNGB           CN
# 55966         2022-07-09          2022-08-20        CNNGB           CN
# 55967         2022-02-25          2022-04-10        TWKHH           TW
# 55968         2022-07-18          2022-08-12        CNSHA           CN
# 55969         2022-07-18          2022-08-12        CNSHA           CN
#
#       PORT_OF_DISCHARGE DISCHARGE_COUNTRY DESTINATION_LOC DESTINATION_COUNTRY  \
# 0                 USSEA                US           USSEA                  US
# 1                 USSEA                US           USSEA                  US
# 2                 USORF                US           USORF                  US
# 4                 USLGB                US           USATL                  US
# 5                 USNYC                US           USNYC                  US
# ...                 ...               ...             ...                 ...
# 55965             USSAV                US           USSAV                  US
# 55966             USSAV                US           USSAV                  US
# 55967             USLGB                US           USGYR                  US
# 55968             USLAX                US           USCRU                  US
# 55969             USLAX                US           USCRU                  US
#
#       CARRIER  holiday  y_depart  route  delay_d  delay_a  quarter  \
# 0        MAEU        0        45     45        9        0        1
# 1        MAEU        0        45     45        9        0        1
# 2        MAEU        0         9      9        0        2        1
# 4        YASV        0        20     20        1        6        1
# 5        DMAL        0        47     47        1       10        1
# ...       ...      ...       ...    ...      ...      ...      ...
# 55965    EGLV        0        42     42        0        7        3
# 55966    EGLV        0        42     42        0        7        3
# 55967    OOLU        0        44     44        0       22        1
# 55968    MAEU        0        25     25        0        2        3
# 55969    MAEU        0        25     25        0        2        3
#
#       departure_day
# 0            Friday
# 1            Friday
# 2            Sunday
# 4          Saturday
# 5            Monday
# ...             ...
# 55965      Saturday
# 55966      Saturday
# 55967        Friday
# 55968        Monday
# 55969        Monday
#
# [40920 rows x 20 columns]
#                     REFERENCE#  CUSTOMER SCHEDULED_ETA SCHEDULED_ETD  \
# 38       6346898550BMOU4409690       250    2022-12-26    2022-11-05
# 43       6346898550GESU6822200       250    2022-12-26    2022-11-05
# 66        292779362MNBU4369536       250    2023-01-14    2022-12-11
# 223       292779558MSKU9481073       250    2023-01-28    2022-12-27
# 226    143266062645EITU9228778       250    2023-01-06    2022-12-11
# ...                        ...       ...           ...           ...
# 43510    6348619971CSNU6448728       250    2023-01-22    2022-12-08
# 43542    2710078851OOLU7694214      3294    2023-01-10    2022-12-11
# 43551    6347416312CSNU4080719       250    2023-01-01    2022-11-19
# 43564    6348619592TCKU6497929       250    2023-01-22    2022-12-08
# 43617    6348620531CCLU7825617       250    2023-01-22    2022-12-08
#
#       ACTUAL_DEPART_DATE ACTUAL_ARRIVAL_DATE PORT_OF_LOAD LOAD_COUNTRY  \
# 38            2022-11-07          2023-01-05        CNFOC           CN
# 43            2022-11-07          2023-01-05        CNFOC           CN
# 66            2022-12-12          2023-01-15        CNTAO           CN
# 223           2022-12-28          2023-01-30        CNTAO           CN
# 226           2022-12-11          2023-01-07        CNNGB           CN
# ...                  ...                 ...          ...          ...
# 43510         2022-12-09          2023-01-26        CNFOC           CN
# 43542         2022-12-11          2023-01-13        CNYTN           CN
# 43551         2022-11-21          2023-01-07        CNFOC           CN
# 43564         2022-12-09          2023-01-26        CNFOC           CN
# 43617         2022-12-09          2023-01-26        CNFOC           CN
#
#       PORT_OF_DISCHARGE DISCHARGE_COUNTRY DESTINATION_LOC DESTINATION_COUNTRY  \
# 38                USSAV                US           USSAV                  US
# 43                USSAV                US           USSAV                  US
# 66                USSEA                US           USSEA                  US
# 223               USSEA                US           USSEA                  US
# 226               USTIW                US           USTIW                  US
# ...                 ...               ...             ...                 ...
# 43510             USORF                US           USORF                  US
# 43542             USNYC                US            CXMI                  US
# 43551             USORF                US           USORF                  US
# 43564             USORF                US           USORF                  US
# 43617             USORF                US           USORF                  US
#
#       CARRIER  holiday  y_depart  route  delay_d  delay_a  quarter  \
# 38       COSU        0        59     59        2       10        4
# 43       COSU        0        59     59        2       10        4
# 66       MAEU        0        34     34        1        1        4
# 223      MAEU        0        33     33        1        2        4
# 226      EGLV        0        27     27        0        1        4
# ...       ...      ...       ...    ...      ...      ...      ...
# 43510    COSU        0        48     48        1        4        4
# 43542    OOLU        0        33     33        0        3        4
# 43551    COSU        0        47     47        2        6        4
# 43564    COSU        0        48     48        1        4        4
# 43617    COSU        0        48     48        1        4        4
#
#       departure_day
# 38           Monday
# 43           Monday
# 66           Monday
# 223       Wednesday
# 226          Sunday
# ...             ...
# 43510        Friday
# 43542        Sunday
# 43551        Monday
# 43564        Friday
# 43617        Friday
#
# [2709 rows x 20 columns]

# %%
new_df = customer_clean[['PORT_OF_LOAD', 'PORT_OF_DISCHARGE', 'y_depart', 'CARRIER', 'ACTUAL_ARRIVAL_DATE']]
new_df.to_csv('/content/drive/MyDrive/new_df.csv', encoding='utf-8')

# %% [markdown]
# ### Setting Up Statistical Features on Training Set

# %%
# Calculate y statistics
stat_route_y = (train.groupby(['CARRIER', 'PORT_OF_LOAD', 'PORT_OF_DISCHARGE'])['y_depart']
                    .mean().reset_index().rename(columns={'y_depart': 'mean_all_departed'}))
stat_route_y['mean_all_departed'] = round(stat_route_y['mean_all_departed'], 2)

# Calculate schedule statistics
stat_schedule = (train.drop_duplicates(['PORT_OF_LOAD', 'PORT_OF_DISCHARGE', 'CARRIER', 'SCHEDULED_ETD', 'SCHEDULED_ETA'])
                  .groupby(['CARRIER', 'PORT_OF_LOAD', 'PORT_OF_DISCHARGE', 'departure_day'])['route']
                  .agg([np.mean, np.count_nonzero]).reset_index()
                  .rename(columns={'mean': 'schedule', 'count_nonzero': 'N'}))
stat_schedule = stat_schedule[stat_schedule['N'] > 4].drop('N', axis=1)
stat_schedule['schedule'] = round(stat_schedule['schedule'], 1)
stat_schedule['departure_day'] = stat_schedule['departure_day'].astype(str)
stat_schedule = stat_schedule.reset_index(drop=True)

# Calculate route statistics
stat_route = (train.drop_duplicates(['PORT_OF_LOAD', 'PORT_OF_DISCHARGE', 'CARRIER', 'SCHEDULED_ETD', 'SCHEDULED_ETA'])
              .groupby(['CARRIER', 'PORT_OF_LOAD', 'PORT_OF_DISCHARGE'])['route']
              .agg([np.mean]).reset_index()
              .rename(columns={'mean': 'route_mean'}))
stat_route['route_mean'] = round(stat_route['route_mean'], 1)
stat_route = stat_route[stat_route['route_mean'].isna() == False]

# Calculate quarter statistics
stat_quarter = (train.groupby('quarter')['y_depart']
                .mean().reset_index()
                .rename(columns={'y_depart': 'quarter_mean'}))
stat_quarter['quarter_mean'] = round(stat_quarter['quarter_mean'], 4)
stat_quarter['quarter'] = stat_quarter['quarter'].astype(int)
stat_quarter['quarter_mean'] = stat_quarter['quarter_mean'].astype(int)

# %%
stat_route_y.to_csv('/content/drive/MyDrive/stat_route_y.csv', encoding='utf-8')
stat_schedule.to_csv('/content/drive/MyDrive/stat_schedule.csv', encoding='utf-8')
stat_route.to_csv('/content/drive/MyDrive/stat_route.csv', encoding='utf-8')
stat_quarter.to_csv('/content/drive/MyDrive/stat_quarter.csv', encoding='utf-8')

# %%
#calculate late_departure_prob, average_arrival_delay , average_departure_delay from the historical_delays df and then keep carrier, quarter and these 3 new columns
historical_delays = train[['CARRIER', 'quarter', 'ACTUAL_DEPART_DATE', 'ACTUAL_ARRIVAL_DATE', 'SCHEDULED_ETD', 'SCHEDULED_ETA']]

# Calculate a boolean indicator for late departures
historical_delays['is_late_departure'] = (historical_delays['ACTUAL_DEPART_DATE'] - historical_delays['SCHEDULED_ETD']).dt.days > 0

# Calculate the late departure probability by carrier and quarter
late_departure_summary = historical_delays.groupby(['CARRIER', 'quarter'])['is_late_departure'].mean().reset_index(name='late_departure_prob')

# Merge this summary back into the original DataFrame
historical_delays = historical_delays.merge(late_departure_summary, on=['CARRIER', 'quarter'], how='left')

historical_delays['average_arrival_delay'] = (historical_delays['ACTUAL_ARRIVAL_DATE'] - historical_delays['SCHEDULED_ETA']).dt.days
historical_delays['average_departure_delay'] = (historical_delays['ACTUAL_DEPART_DATE'] - historical_delays['SCHEDULED_ETD']).dt.days

historical_delays = historical_delays[['CARRIER', 'quarter', 'late_departure_prob', 'average_arrival_delay', 'average_departure_delay']]
# Out:
# <ipython-input-9-94652de81202>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   historical_delays['is_late_departure'] = (historical_delays['ACTUAL_DEPART_DATE'] - historical_delays['SCHEDULED_ETD']).dt.days > 0

# %%
historical_delays.to_csv('/content/drive/MyDrive/historical_delays.csv', encoding='utf-8')

# %%
def get_features_departed(df, model=False):
    # Update column references to match the provided code
    df = df[df['ACTUAL_DEPART_DATE'].isna() == False]
    day_to_num = {'Monday': 1, 'Tuesday': 2, 'Wednesday': 3, 'Thursday': 4, 'Friday': 5, 'Saturday': 6, 'Sunday': 7}
    df['departure_day'] = df['ACTUAL_DEPART_DATE'].dt.strftime('%A').map(day_to_num)
    df['late_departure'] = np.where((df['ACTUAL_DEPART_DATE'] - df['SCHEDULED_ETD']).dt.days > 0, 1, 0)  # if vessel left after scheduled time
    df['quarter'] = df['SCHEDULED_ETD'].dt.quarter

    # Ensure 'departure_day' is string (object) in all relevant dataframes
    df['departure_day'] = df['departure_day'].astype(str)


    # Ensure 'quarter' is int64 in all relevant dataframes
    df['quarter'] = df['quarter'].astype(int)



    print('created depart columns...')
    new_transports = (df.merge(stat_route_y, on=['CARRIER', 'PORT_OF_LOAD', 'PORT_OF_DISCHARGE'], how='left')
                        .merge(stat_route, on=['CARRIER', 'PORT_OF_LOAD', 'PORT_OF_DISCHARGE'], how='left')
                        .merge(stat_schedule, on=['CARRIER', 'PORT_OF_LOAD', 'PORT_OF_DISCHARGE', 'departure_day'], how='left')
                        .merge(stat_quarter, on='quarter', how='left'))

    new_transports['schedule'] = np.where(new_transports['schedule'].isna(),
                                          new_transports['route_mean'],
                                          new_transports['schedule'])

    print('merged depart statistics...')

    features = ['quarter', 'mean_all_departed', 'route_mean', 'late_departure', 'schedule','delay_a','delay_d']

    if model:
        features += ['y_depart']
        # Drop impossible samples
        new_transports = new_transports[(new_transports['y_depart'] > 0) & (new_transports['y_depart'] < 71)]
        return new_transports, features

    # create new df for prediction or analysis
    return new_transports[features], features

# %% [markdown]
# ## Model Training and Evaluation

# %% [markdown]
# ### Random Forest Regressor

# %%
# Load model data for "Departed"
print('Start to load model data for "Departed"...')
model_departed, features = get_features_departed(train, model=True)
print(model_departed.columns)  # Add this before the dropna call
model_ready = model_departed.dropna(subset=features)

model_ready = model_departed
print('Model for "Departed" is ready...')

# Select relevant columns
model_ready = model_ready[features]

# Data preparation for model
model_ready = model_ready.rename(columns={'y_depart': 'y'})

X = model_ready.drop('y', axis=1)
y = model_ready['y']
trees = 500
depth = 5  # Preset depth for "Departed" model
# Out:
# Start to load model data for "Departed"...
# created depart columns...
# merged depart statistics...
# Index(['REFERENCE#', 'CUSTOMER', 'SCHEDULED_ETA', 'SCHEDULED_ETD',
#        'ACTUAL_DEPART_DATE', 'ACTUAL_ARRIVAL_DATE', 'PORT_OF_LOAD',
#        'LOAD_COUNTRY', 'PORT_OF_DISCHARGE', 'DISCHARGE_COUNTRY',
#        'DESTINATION_LOC', 'DESTINATION_COUNTRY', 'CARRIER', 'holiday',
#        'y_depart', 'route', 'delay_d', 'delay_a', 'quarter', 'departure_day',
#        'late_departure', 'mean_all_departed', 'route_mean', 'schedule',
#        'quarter_mean'],
#       dtype='object')
# Model for "Departed" is ready...

# %%
# Train the random forest model
print('Begin training model for "Departed"...')
rf = randomforest(max_depth=depth, trees=trees, features='sqrt')

# Train the model
rf.fit(X, y)

# Save the trained model
filename = '/content/randomforest_depart_new.joblib'
joblib.dump(rf, filename)

print('Model training complete and saved.')
# Out:
# Begin training model for "Departed"...
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 500
# building tree 2 of 500
# building tree 3 of 500[Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.0s
#
# building tree 4 of 500
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# building tree 5 of 500[Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.1s
# building tree 6 of 500
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.1s
#
# building tree 7 of 500[Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.1s
#
# building tree 8 of 500
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    0.1s
# building tree 9 of 500[Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.1s
#
# building tree 10 of 500[Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.1s
#
# building tree 11 of 500[Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    0.1s
#
# building tree 12 of 500[Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.1s
#
# building tree 13 of 500[Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    0.1s
#
# building tree 14 of 500[Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    0.2s
#
# building tree 15 of 500
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.2s
# building tree 16 of 500[Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    0.2s
#
# building tree 17 of 500[Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    0.2s
#
# building tree 18 of 500[Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    0.2s
#
# building tree 19 of 500[Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.2s
#
# building tree 20 of 500[Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.2s
#
# building tree 21 of 500[Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    0.2s
#
# building tree 22 of 500[Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    0.2s
#
# building tree 23 of 500[Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.2s
#
# building tree 24 of 500[Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    0.2s
#
# building tree 25 of 500[Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:    0.2s
#
# building tree 26 of 500[Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.3s
#
# building tree 27 of 500[Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    0.3s
#
# building tree 28 of 500[Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.3s
#
# building tree 29 of 500[Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.3s
#
# building tree 30 of 500[Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.3s
#
# building tree 31 of 500[Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    0.3s
#
# building tree 32 of 500[Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.3s
# building tree 33 of 500
#
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:    0.3s
# building tree 34 of 500
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    0.4s
# building tree 35 of 500[Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    0.4s
#
# building tree 36 of 500[Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.4s
#
# building tree 37 of 500[Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:    0.4s
#
# building tree 38 of 500[Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:    0.4s
#
# building tree 39 of 500[Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.4s
#
# building tree 40 of 500[Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    0.4s
#
# building tree 41 of 500[Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:    0.4s
#
# building tree 42 of 500[Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    0.4s
#
# building tree 43 of 500[Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:    0.4s
#
# building tree 44 of 500[Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.4s
#
# building tree 45 of 500[Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:    0.5s
#
# building tree 46 of 500[Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:    0.5s
#
# building tree 47 of 500[Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:    0.5s
#
# building tree 48 of 500[Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:    0.5s
#
# building tree 49 of 500[Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:    0.5s
#
# building tree 50 of 500[Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:    0.5s
#
# building tree 51 of 500[Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:    0.5s
#
# building tree 52 of 500[Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:    0.5s
#
# building tree 53 of 500[Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:    0.5s
#
# building tree 54 of 500[Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.6s
#
# building tree 55 of 500[Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    0.6s
#
# building tree 56 of 500[Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:    0.6s
#
# building tree 57 of 500[Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:    0.6s
#
# building tree 58 of 500[Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    0.6s
#
# building tree 59 of 500[Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:    0.6s
#
# building tree 60 of 500[Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:    0.6s
#
# building tree 61 of 500[Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:    0.6s
#
# building tree 62 of 500[Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:    0.6s
#
# building tree 63 of 500[Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:    0.6s
#
# building tree 64 of 500[Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:    0.7s
#
# building tree 65 of 500
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:    0.7s
# building tree 66 of 500[Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    0.7s
# building tree 67 of 500
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:    0.7s
#
# building tree 68 of 500[Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:    0.7s
#
# building tree 69 of 500[Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:    0.7s
#
# building tree 70 of 500[Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:    0.7s
#
# building tree 71 of 500[Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:    0.7s
#
# building tree 72 of 500[Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:    0.8s
#
# building tree 73 of 500[Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:    0.8s
#
# building tree 74 of 500[Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:    0.8s
#
# building tree 75 of 500[Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:    0.8s
#
# building tree 76 of 500[Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:    0.8s
#
# building tree 77 of 500[Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:    0.8s
#
# building tree 78 of 500[Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    0.8s
#
# building tree 79 of 500[Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:    0.8s
#
# building tree 80 of 500[Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:    0.8s
#
# building tree 81 of 500[Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:    0.8s
#
# building tree 82 of 500
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:    0.8s
# building tree 83 of 500
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:    0.9s
# building tree 84 of 500
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    0.9s
# building tree 85 of 500[Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:    0.9s
#
# building tree 86 of 500[Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:    0.9s
#
# building tree 87 of 500[Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:    0.9s
#
# building tree 88 of 500[Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:    0.9s
#
# building tree 89 of 500[Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:    0.9s
#
# building tree 90 of 500[Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:    0.9s
#
# building tree 91 of 500[Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:    0.9s
#
# building tree 92 of 500[Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:    1.0s
# building tree 93 of 500
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:    1.0s
#
# building tree 94 of 500[Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:    1.0s
#
# building tree 95 of 500[Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:    1.0s
#
# building tree 96 of 500[Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:    1.0s
#
# building tree 97 of 500[Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:    1.0s
#
# building tree 98 of 500[Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:    1.0s
#
# building tree 99 of 500[Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:    1.0s
#
# building tree 100 of 500[Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:    1.0s
#
# building tree 101 of 500[Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:    1.1s
#
# building tree 102 of 500[Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:    1.1s
#
# building tree 103 of 500[Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:    1.1s
#
# building tree 104 of 500[Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:    1.1s
#
# building tree 105 of 500[Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:    1.1s
#
# building tree 106 of 500
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:    1.1s
# building tree 107 of 500[Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:    1.1s
#
# building tree 108 of 500[Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:    1.1s
#
# building tree 109 of 500[Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:    1.1s
#
# building tree 110 of 500
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:    1.1s
# building tree 111 of 500[Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:    1.2s
#
# building tree 112 of 500[Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:    1.2s
#
# building tree 113 of 500[Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:    1.2s
#
# building tree 114 of 500[Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    1.2s
#
# building tree 115 of 500building tree 116 of 500
#
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:    1.2s
# building tree 117 of 500[Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:    1.2s
#
# building tree 118 of 500[Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:    1.2s
#
# building tree 119 of 500[Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:    1.2s
#
# building tree 120 of 500[Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:    1.2s
#
# building tree 121 of 500[Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:    1.2s
#
# building tree 122 of 500
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:    1.3s
# building tree 123 of 500[Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:    1.3s
#
# building tree 124 of 500[Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:    1.3s
#
# building tree 125 of 500[Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:    1.3s
#
# building tree 126 of 500[Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:    1.3s
#
# building tree 127 of 500[Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:    1.3s
#
# building tree 128 of 500[Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:    1.3s
#
# building tree 129 of 500[Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:    1.3s
#
# building tree 130 of 500[Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:    1.3s
#
# building tree 131 of 500[Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:    1.3s
#
# building tree 132 of 500[Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    1.4s
#
# building tree 133 of 500[Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:    1.4s
#
# building tree 134 of 500[Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:    1.4s
#
# building tree 135 of 500[Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:    1.4s
#
# building tree 136 of 500[Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:    1.4s
#
# building tree 137 of 500[Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:    1.4s
#
# building tree 138 of 500[Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:    1.4s
#
# building tree 139 of 500[Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:    1.4s
#
# building tree 140 of 500[Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:    1.4s
#
# building tree 141 of 500
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed:    1.4s
# building tree 142 of 500[Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed:    1.5s
#
# building tree 143 of 500[Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:    1.5s
#
# building tree 144 of 500[Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed:    1.5s
#
# building tree 145 of 500[Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed:    1.5s
#
# building tree 146 of 500[Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:    1.5s
#
# building tree 147 of 500[Parallel(n_jobs=-1)]: Done 145 tasks      | elapsed:    1.5s
#
# building tree 148 of 500[Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:    1.5s
#
# building tree 149 of 500[Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed:    1.5s
#
# building tree 150 of 500[Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:    1.5s
#
# building tree 151 of 500[Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:    1.5s
#
# building tree 152 of 500[Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:    1.6s
#
# building tree 153 of 500[Parallel(n_jobs=-1)]: Done 151 tasks      | elapsed:    1.6s
#
# building tree 154 of 500[Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:    1.6s
#
# building tree 155 of 500
# [Parallel(n_jobs=-1)]: Done 153 tasks      | elapsed:    1.6s
# building tree 156 of 500[Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:    1.6s
#
# building tree 157 of 500[Parallel(n_jobs=-1)]: Done 155 tasks      | elapsed:    1.6s
#
# building tree 158 of 500[Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:    1.6s
#
# building tree 159 of 500[Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:    1.6s
#
# building tree 160 of 500[Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:    1.6s
#
# building tree 161 of 500[Parallel(n_jobs=-1)]: Done 159 tasks      | elapsed:    1.6s
#
# building tree 162 of 500
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:    1.7s
# building tree 163 of 500
# [Parallel(n_jobs=-1)]: Done 161 tasks      | elapsed:    1.7s
# building tree 164 of 500[Parallel(n_jobs=-1)]: Done 162 tasks      | elapsed:    1.7s
#
# building tree 165 of 500
# [Parallel(n_jobs=-1)]: Done 163 tasks      | elapsed:    1.7s
# building tree 166 of 500[Parallel(n_jobs=-1)]: Done 164 tasks      | elapsed:    1.7s
#
# building tree 167 of 500[Parallel(n_jobs=-1)]: Done 165 tasks      | elapsed:    1.7s
#
# building tree 168 of 500[Parallel(n_jobs=-1)]: Done 166 tasks      | elapsed:    1.7s
#
# building tree 169 of 500[Parallel(n_jobs=-1)]: Done 167 tasks      | elapsed:    1.7s
#
# building tree 170 of 500[Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:    1.7s
#
# building tree 171 of 500
# [Parallel(n_jobs=-1)]: Done 169 tasks      | elapsed:    1.7s
# building tree 172 of 500[Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:    1.8s
#
# building tree 173 of 500[Parallel(n_jobs=-1)]: Done 171 tasks      | elapsed:    1.8s
#
# building tree 174 of 500[Parallel(n_jobs=-1)]: Done 172 tasks      | elapsed:    1.8s
#
# building tree 175 of 500[Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:    1.8s
#
# building tree 176 of 500[Parallel(n_jobs=-1)]: Done 174 tasks      | elapsed:    1.8s
# building tree 177 of 500
# [Parallel(n_jobs=-1)]: Done 175 tasks      | elapsed:    1.8s
#
# building tree 178 of 500[Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:    1.8s
#
# building tree 179 of 500[Parallel(n_jobs=-1)]: Done 177 tasks      | elapsed:    1.8s
#
# building tree 180 of 500[Parallel(n_jobs=-1)]: Done 178 tasks      | elapsed:    1.8s
#
# building tree 181 of 500[Parallel(n_jobs=-1)]: Done 179 tasks      | elapsed:    1.8s
#
# building tree 182 of 500[Parallel(n_jobs=-1)]: Done 180 tasks      | elapsed:    1.9s
#
# building tree 183 of 500
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:    1.9s
# building tree 184 of 500[Parallel(n_jobs=-1)]: Done 182 tasks      | elapsed:    1.9s
#
# building tree 185 of 500
# [Parallel(n_jobs=-1)]: Done 183 tasks      | elapsed:    1.9s
# building tree 186 of 500[Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    1.9s
#
# building tree 187 of 500[Parallel(n_jobs=-1)]: Done 185 tasks      | elapsed:    1.9s
#
# building tree 188 of 500[Parallel(n_jobs=-1)]: Done 186 tasks      | elapsed:    1.9s
#
# building tree 189 of 500
# [Parallel(n_jobs=-1)]: Done 187 tasks      | elapsed:    1.9s
# building tree 190 of 500[Parallel(n_jobs=-1)]: Done 188 tasks      | elapsed:    1.9s
#
# building tree 191 of 500[Parallel(n_jobs=-1)]: Done 189 tasks      | elapsed:    2.0s
#
# building tree 192 of 500[Parallel(n_jobs=-1)]: Done 190 tasks      | elapsed:    2.0s
#
# building tree 193 of 500
# [Parallel(n_jobs=-1)]: Done 191 tasks      | elapsed:    2.0s
# building tree 194 of 500[Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:    2.0s
#
# building tree 195 of 500[Parallel(n_jobs=-1)]: Done 193 tasks      | elapsed:    2.0s
#
# building tree 196 of 500
# [Parallel(n_jobs=-1)]: Done 194 tasks      | elapsed:    2.0s
# building tree 197 of 500[Parallel(n_jobs=-1)]: Done 195 tasks      | elapsed:    2.0s
#
# building tree 198 of 500[Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:    2.0s
#
# building tree 199 of 500[Parallel(n_jobs=-1)]: Done 197 tasks      | elapsed:    2.0s
#
# building tree 200 of 500[Parallel(n_jobs=-1)]: Done 198 tasks      | elapsed:    2.0s
#
# building tree 201 of 500[Parallel(n_jobs=-1)]: Done 199 tasks      | elapsed:    2.1s
#
# building tree 202 of 500[Parallel(n_jobs=-1)]: Done 200 tasks      | elapsed:    2.1s
#
# building tree 203 of 500
# [Parallel(n_jobs=-1)]: Done 201 tasks      | elapsed:    2.1s
# building tree 204 of 500[Parallel(n_jobs=-1)]: Done 202 tasks      | elapsed:    2.1s
#
# building tree 205 of 500[Parallel(n_jobs=-1)]: Done 203 tasks      | elapsed:    2.1s
#
# building tree 206 of 500
# [Parallel(n_jobs=-1)]: Done 204 tasks      | elapsed:    2.1s
# building tree 207 of 500[Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:    2.1s
#
# building tree 208 of 500[Parallel(n_jobs=-1)]: Done 206 tasks      | elapsed:    2.1s
#
# building tree 209 of 500[Parallel(n_jobs=-1)]: Done 207 tasks      | elapsed:    2.1s
#
# building tree 210 of 500[Parallel(n_jobs=-1)]: Done 208 tasks      | elapsed:    2.1s
#
# building tree 211 of 500[Parallel(n_jobs=-1)]: Done 209 tasks      | elapsed:    2.2s
#
# building tree 212 of 500[Parallel(n_jobs=-1)]: Done 210 tasks      | elapsed:    2.2s
#
# building tree 213 of 500
# [Parallel(n_jobs=-1)]: Done 211 tasks      | elapsed:    2.2s
# building tree 214 of 500
# [Parallel(n_jobs=-1)]: Done 212 tasks      | elapsed:    2.2s
# building tree 215 of 500[Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:    2.2s
#
# building tree 216 of 500[Parallel(n_jobs=-1)]: Done 214 tasks      | elapsed:    2.2s
#
# building tree 217 of 500[Parallel(n_jobs=-1)]: Done 215 tasks      | elapsed:    2.2s
#
# building tree 218 of 500[Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:    2.2s
#
# building tree 219 of 500[Parallel(n_jobs=-1)]: Done 217 tasks      | elapsed:    2.2s
#
# building tree 220 of 500[Parallel(n_jobs=-1)]: Done 218 tasks      | elapsed:    2.3s
#
# building tree 221 of 500[Parallel(n_jobs=-1)]: Done 219 tasks      | elapsed:    2.3s
#
# building tree 222 of 500[Parallel(n_jobs=-1)]: Done 220 tasks      | elapsed:    2.3s
#
# building tree 223 of 500[Parallel(n_jobs=-1)]: Done 221 tasks      | elapsed:    2.3s
#
# building tree 224 of 500[Parallel(n_jobs=-1)]: Done 222 tasks      | elapsed:    2.3s
# building tree 225 of 500
# [Parallel(n_jobs=-1)]: Done 223 tasks      | elapsed:    2.3s
#
# building tree 226 of 500[Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:    2.3s
#
# building tree 227 of 500
# [Parallel(n_jobs=-1)]: Done 225 tasks      | elapsed:    2.3s
# building tree 228 of 500[Parallel(n_jobs=-1)]: Done 226 tasks      | elapsed:    2.3s
#
# building tree 229 of 500[Parallel(n_jobs=-1)]: Done 227 tasks      | elapsed:    2.3s
#
# building tree 230 of 500[Parallel(n_jobs=-1)]: Done 228 tasks      | elapsed:    2.3s
#
# building tree 231 of 500[Parallel(n_jobs=-1)]: Done 229 tasks      | elapsed:    2.3s
#
# building tree 232 of 500[Parallel(n_jobs=-1)]: Done 230 tasks      | elapsed:    2.4s
#
# building tree 233 of 500[Parallel(n_jobs=-1)]: Done 231 tasks      | elapsed:    2.4s
#
# building tree 234 of 500[Parallel(n_jobs=-1)]: Done 232 tasks      | elapsed:    2.4s
#
# building tree 235 of 500[Parallel(n_jobs=-1)]: Done 233 tasks      | elapsed:    2.4s
#
# building tree 236 of 500[Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:    2.4s
#
# building tree 237 of 500[Parallel(n_jobs=-1)]: Done 235 tasks      | elapsed:    2.4s
#
# building tree 238 of 500[Parallel(n_jobs=-1)]: Done 236 tasks      | elapsed:    2.4s
#
# building tree 239 of 500[Parallel(n_jobs=-1)]: Done 237 tasks      | elapsed:    2.4s
#
# building tree 240 of 500[Parallel(n_jobs=-1)]: Done 238 tasks      | elapsed:    2.4s
#
# building tree 241 of 500[Parallel(n_jobs=-1)]: Done 239 tasks      | elapsed:    2.5s
#
# building tree 242 of 500
# [Parallel(n_jobs=-1)]: Done 240 tasks      | elapsed:    2.5s
# building tree 243 of 500[Parallel(n_jobs=-1)]: Done 241 tasks      | elapsed:    2.5s
#
# building tree 244 of 500[Parallel(n_jobs=-1)]: Done 242 tasks      | elapsed:    2.5s
#
# building tree 245 of 500[Parallel(n_jobs=-1)]: Done 243 tasks      | elapsed:    2.5s
#
# building tree 246 of 500[Parallel(n_jobs=-1)]: Done 244 tasks      | elapsed:    2.5s
#
# building tree 247 of 500[Parallel(n_jobs=-1)]: Done 245 tasks      | elapsed:    2.5s
#
# building tree 248 of 500[Parallel(n_jobs=-1)]: Done 246 tasks      | elapsed:    2.5s
#
# building tree 249 of 500
# [Parallel(n_jobs=-1)]: Done 247 tasks      | elapsed:    2.5s
# building tree 250 of 500[Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed:    2.5s
#
# building tree 251 of 500[Parallel(n_jobs=-1)]: Done 249 tasks      | elapsed:    2.5s
#
# building tree 252 of 500[Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    2.6s
#
# building tree 253 of 500
# [Parallel(n_jobs=-1)]: Done 251 tasks      | elapsed:    2.6s
# building tree 254 of 500[Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.6s
#
# building tree 255 of 500[Parallel(n_jobs=-1)]: Done 253 tasks      | elapsed:    2.6s
#
# building tree 256 of 500[Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:    2.6s
#
# building tree 257 of 500[Parallel(n_jobs=-1)]: Done 255 tasks      | elapsed:    2.6s
#
# building tree 258 of 500[Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    2.6s
#
# building tree 259 of 500[Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:    2.6s
#
# building tree 260 of 500[Parallel(n_jobs=-1)]: Done 258 tasks      | elapsed:    2.6s
#
# building tree 261 of 500[Parallel(n_jobs=-1)]: Done 259 tasks      | elapsed:    2.7s
#
# building tree 262 of 500[Parallel(n_jobs=-1)]: Done 260 tasks      | elapsed:    2.7s
#
# building tree 263 of 500[Parallel(n_jobs=-1)]: Done 261 tasks      | elapsed:    2.7s
# building tree 264 of 500
# [Parallel(n_jobs=-1)]: Done 262 tasks      | elapsed:    2.7s
#
# building tree 265 of 500[Parallel(n_jobs=-1)]: Done 263 tasks      | elapsed:    2.7s
#
# building tree 266 of 500[Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed:    2.7s
#
# building tree 267 of 500[Parallel(n_jobs=-1)]: Done 265 tasks      | elapsed:    2.7s
#
# building tree 268 of 500[Parallel(n_jobs=-1)]: Done 266 tasks      | elapsed:    2.7s
#
# building tree 269 of 500[Parallel(n_jobs=-1)]: Done 267 tasks      | elapsed:    2.7s
#
# building tree 270 of 500[Parallel(n_jobs=-1)]: Done 268 tasks      | elapsed:    2.7s
#
# building tree 271 of 500[Parallel(n_jobs=-1)]: Done 269 tasks      | elapsed:    2.7s
#
# building tree 272 of 500[Parallel(n_jobs=-1)]: Done 270 tasks      | elapsed:    2.8s
#
# building tree 273 of 500[Parallel(n_jobs=-1)]: Done 271 tasks      | elapsed:    2.8s
#
# building tree 274 of 500[Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:    2.8s
#
# building tree 275 of 500[Parallel(n_jobs=-1)]: Done 273 tasks      | elapsed:    2.8s
#
# building tree 276 of 500
# [Parallel(n_jobs=-1)]: Done 274 tasks      | elapsed:    2.8s
# building tree 277 of 500[Parallel(n_jobs=-1)]: Done 275 tasks      | elapsed:    2.8s
#
# building tree 278 of 500[Parallel(n_jobs=-1)]: Done 276 tasks      | elapsed:    2.8s
#
# building tree 279 of 500[Parallel(n_jobs=-1)]: Done 277 tasks      | elapsed:    2.8s
#
# building tree 280 of 500[Parallel(n_jobs=-1)]: Done 278 tasks      | elapsed:    2.8s
#
# building tree 281 of 500
# [Parallel(n_jobs=-1)]: Done 279 tasks      | elapsed:    2.8s
# building tree 282 of 500[Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:    2.8s
#
# building tree 283 of 500[Parallel(n_jobs=-1)]: Done 281 tasks      | elapsed:    2.9s
#
# building tree 284 of 500[Parallel(n_jobs=-1)]: Done 282 tasks      | elapsed:    2.9s
#
# building tree 285 of 500[Parallel(n_jobs=-1)]: Done 283 tasks      | elapsed:    2.9s
#
# building tree 286 of 500[Parallel(n_jobs=-1)]: Done 284 tasks      | elapsed:    2.9s
#
# building tree 287 of 500[Parallel(n_jobs=-1)]: Done 285 tasks      | elapsed:    2.9s
#
# building tree 288 of 500[Parallel(n_jobs=-1)]: Done 286 tasks      | elapsed:    2.9s
#
# building tree 289 of 500[Parallel(n_jobs=-1)]: Done 287 tasks      | elapsed:    2.9s
#
# building tree 290 of 500[Parallel(n_jobs=-1)]: Done 288 tasks      | elapsed:    2.9s
#
# building tree 291 of 500[Parallel(n_jobs=-1)]: Done 289 tasks      | elapsed:    2.9s
#
# building tree 292 of 500[Parallel(n_jobs=-1)]: Done 290 tasks      | elapsed:    3.0s
#
# building tree 293 of 500[Parallel(n_jobs=-1)]: Done 291 tasks      | elapsed:    3.0s
#
# building tree 294 of 500[Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:    3.0s
#
# building tree 295 of 500
# [Parallel(n_jobs=-1)]: Done 293 tasks      | elapsed:    3.0s
# building tree 296 of 500[Parallel(n_jobs=-1)]: Done 294 tasks      | elapsed:    3.0s
#
# building tree 297 of 500[Parallel(n_jobs=-1)]: Done 295 tasks      | elapsed:    3.0s
#
# building tree 298 of 500[Parallel(n_jobs=-1)]: Done 296 tasks      | elapsed:    3.0s
#
# building tree 299 of 500[Parallel(n_jobs=-1)]: Done 297 tasks      | elapsed:    3.0s
#
# building tree 300 of 500[Parallel(n_jobs=-1)]: Done 298 tasks      | elapsed:    3.0s
#
# building tree 301 of 500[Parallel(n_jobs=-1)]: Done 299 tasks      | elapsed:    3.0s
#
# building tree 302 of 500
# [Parallel(n_jobs=-1)]: Done 300 tasks      | elapsed:    3.1s
# building tree 303 of 500[Parallel(n_jobs=-1)]: Done 301 tasks      | elapsed:    3.1s
#
# building tree 304 of 500
# [Parallel(n_jobs=-1)]: Done 302 tasks      | elapsed:    3.1s
# building tree 305 of 500[Parallel(n_jobs=-1)]: Done 303 tasks      | elapsed:    3.1s
#
# building tree 306 of 500[Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:    3.1s
#
# building tree 307 of 500[Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:    3.1s
#
# building tree 308 of 500[Parallel(n_jobs=-1)]: Done 306 tasks      | elapsed:    3.1s
#
# building tree 309 of 500[Parallel(n_jobs=-1)]: Done 307 tasks      | elapsed:    3.1s
#
# building tree 310 of 500[Parallel(n_jobs=-1)]: Done 308 tasks      | elapsed:    3.1s
#
# building tree 311 of 500[Parallel(n_jobs=-1)]: Done 309 tasks      | elapsed:    3.1s
#
# building tree 312 of 500[Parallel(n_jobs=-1)]: Done 310 tasks      | elapsed:    3.2s
#
# building tree 313 of 500[Parallel(n_jobs=-1)]: Done 311 tasks      | elapsed:    3.2s
#
# building tree 314 of 500[Parallel(n_jobs=-1)]: Done 312 tasks      | elapsed:    3.2s
#
# building tree 315 of 500[Parallel(n_jobs=-1)]: Done 313 tasks      | elapsed:    3.2s
#
# building tree 316 of 500[Parallel(n_jobs=-1)]: Done 314 tasks      | elapsed:    3.2s
#
# building tree 317 of 500[Parallel(n_jobs=-1)]: Done 315 tasks      | elapsed:    3.2s
#
# building tree 318 of 500[Parallel(n_jobs=-1)]: Done 316 tasks      | elapsed:    3.2s
#
# building tree 319 of 500[Parallel(n_jobs=-1)]: Done 317 tasks      | elapsed:    3.2s
#
# building tree 320 of 500[Parallel(n_jobs=-1)]: Done 318 tasks      | elapsed:    3.2s
#
# building tree 321 of 500[Parallel(n_jobs=-1)]: Done 319 tasks      | elapsed:    3.2s
#
# building tree 322 of 500[Parallel(n_jobs=-1)]: Done 320 tasks      | elapsed:    3.3s
#
# building tree 323 of 500[Parallel(n_jobs=-1)]: Done 321 tasks      | elapsed:    3.3s
#
# building tree 324 of 500[Parallel(n_jobs=-1)]: Done 322 tasks      | elapsed:    3.3s
#
# building tree 325 of 500[Parallel(n_jobs=-1)]: Done 323 tasks      | elapsed:    3.3s
#
# building tree 326 of 500[Parallel(n_jobs=-1)]: Done 324 tasks      | elapsed:    3.3s
#
# building tree 327 of 500[Parallel(n_jobs=-1)]: Done 325 tasks      | elapsed:    3.3s
#
# building tree 328 of 500[Parallel(n_jobs=-1)]: Done 326 tasks      | elapsed:    3.3s
# building tree 329 of 500
#
# [Parallel(n_jobs=-1)]: Done 327 tasks      | elapsed:    3.3s
# building tree 330 of 500[Parallel(n_jobs=-1)]: Done 328 tasks      | elapsed:    3.3s
# building tree 331 of 500[Parallel(n_jobs=-1)]: Done 329 tasks      | elapsed:    3.3s
#
#
# building tree 332 of 500[Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:    3.4s
#
# building tree 333 of 500[Parallel(n_jobs=-1)]: Done 331 tasks      | elapsed:    3.4s
#
# building tree 334 of 500[Parallel(n_jobs=-1)]: Done 332 tasks      | elapsed:    3.4s
#
# building tree 335 of 500[Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed:    3.4s
#
# building tree 336 of 500[Parallel(n_jobs=-1)]: Done 334 tasks      | elapsed:    3.4s
#
# building tree 337 of 500[Parallel(n_jobs=-1)]: Done 335 tasks      | elapsed:    3.4s
#
# building tree 338 of 500[Parallel(n_jobs=-1)]: Done 336 tasks      | elapsed:    3.4s
#
# building tree 339 of 500[Parallel(n_jobs=-1)]: Done 337 tasks      | elapsed:    3.4s
#
# building tree 340 of 500[Parallel(n_jobs=-1)]: Done 338 tasks      | elapsed:    3.4s
#
# building tree 341 of 500[Parallel(n_jobs=-1)]: Done 339 tasks      | elapsed:    3.4s
#
# building tree 342 of 500[Parallel(n_jobs=-1)]: Done 340 tasks      | elapsed:    3.5s
#
# building tree 343 of 500
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:    3.5s
# building tree 344 of 500[Parallel(n_jobs=-1)]: Done 342 tasks      | elapsed:    3.5s
# building tree 345 of 500
#
# [Parallel(n_jobs=-1)]: Done 343 tasks      | elapsed:    3.5s
# building tree 346 of 500[Parallel(n_jobs=-1)]: Done 344 tasks      | elapsed:    3.5s
#
# building tree 347 of 500[Parallel(n_jobs=-1)]: Done 345 tasks      | elapsed:    3.5s
#
# building tree 348 of 500[Parallel(n_jobs=-1)]: Done 346 tasks      | elapsed:    3.5s
#
# building tree 349 of 500[Parallel(n_jobs=-1)]: Done 347 tasks      | elapsed:    3.5s
#
# building tree 350 of 500[Parallel(n_jobs=-1)]: Done 348 tasks      | elapsed:    3.5s
#
# building tree 351 of 500[Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:    3.5s
#
# building tree 352 of 500[Parallel(n_jobs=-1)]: Done 350 tasks      | elapsed:    3.6s
# building tree 353 of 500
# [Parallel(n_jobs=-1)]: Done 351 tasks      | elapsed:    3.6s
#
# building tree 354 of 500[Parallel(n_jobs=-1)]: Done 352 tasks      | elapsed:    3.6s
#
# building tree 355 of 500[Parallel(n_jobs=-1)]: Done 353 tasks      | elapsed:    3.6s
#
# building tree 356 of 500[Parallel(n_jobs=-1)]: Done 354 tasks      | elapsed:    3.6s
# building tree 357 of 500[Parallel(n_jobs=-1)]: Done 355 tasks      | elapsed:    3.6s
#
#
# building tree 358 of 500
# [Parallel(n_jobs=-1)]: Done 356 tasks      | elapsed:    3.6s
# building tree 359 of 500[Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:    3.6s
#
# building tree 360 of 500[Parallel(n_jobs=-1)]: Done 358 tasks      | elapsed:    3.6s
#
# building tree 361 of 500[Parallel(n_jobs=-1)]: Done 359 tasks      | elapsed:    3.7s
#
# building tree 362 of 500[Parallel(n_jobs=-1)]: Done 360 tasks      | elapsed:    3.7s
#
# building tree 363 of 500[Parallel(n_jobs=-1)]: Done 361 tasks      | elapsed:    3.7s
#
# building tree 364 of 500[Parallel(n_jobs=-1)]: Done 362 tasks      | elapsed:    3.7s
#
# building tree 365 of 500[Parallel(n_jobs=-1)]: Done 363 tasks      | elapsed:    3.7s
#
# building tree 366 of 500[Parallel(n_jobs=-1)]: Done 364 tasks      | elapsed:    3.7s
#
# building tree 367 of 500[Parallel(n_jobs=-1)]: Done 365 tasks      | elapsed:    3.7s
#
# building tree 368 of 500[Parallel(n_jobs=-1)]: Done 366 tasks      | elapsed:    3.7s
# building tree 369 of 500[Parallel(n_jobs=-1)]: Done 367 tasks      | elapsed:    3.7s
#
#
# building tree 370 of 500[Parallel(n_jobs=-1)]: Done 368 tasks      | elapsed:    3.7s
# building tree 371 of 500
#
# [Parallel(n_jobs=-1)]: Done 369 tasks      | elapsed:    3.7s
# building tree 372 of 500[Parallel(n_jobs=-1)]: Done 370 tasks      | elapsed:    3.8s
#
# building tree 373 of 500[Parallel(n_jobs=-1)]: Done 371 tasks      | elapsed:    3.8s
#
# building tree 374 of 500[Parallel(n_jobs=-1)]: Done 372 tasks      | elapsed:    3.8s
#
# building tree 375 of 500[Parallel(n_jobs=-1)]: Done 373 tasks      | elapsed:    3.8s
#
# building tree 376 of 500[Parallel(n_jobs=-1)]: Done 374 tasks      | elapsed:    3.8s
#
# building tree 377 of 500[Parallel(n_jobs=-1)]: Done 375 tasks      | elapsed:    3.8s
#
# building tree 378 of 500[Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:    3.8s
#
# building tree 379 of 500[Parallel(n_jobs=-1)]: Done 377 tasks      | elapsed:    3.8s
#
# building tree 380 of 500[Parallel(n_jobs=-1)]: Done 378 tasks      | elapsed:    3.8s
#
# building tree 381 of 500[Parallel(n_jobs=-1)]: Done 379 tasks      | elapsed:    3.8s
#
# building tree 382 of 500[Parallel(n_jobs=-1)]: Done 380 tasks      | elapsed:    3.9s
#
# building tree 383 of 500[Parallel(n_jobs=-1)]: Done 381 tasks      | elapsed:    3.9s
#
# building tree 384 of 500[Parallel(n_jobs=-1)]: Done 382 tasks      | elapsed:    3.9s
#
# building tree 385 of 500[Parallel(n_jobs=-1)]: Done 383 tasks      | elapsed:    3.9s
#
# building tree 386 of 500[Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:    3.9s
#
# building tree 387 of 500[Parallel(n_jobs=-1)]: Done 385 tasks      | elapsed:    3.9s
#
# building tree 388 of 500[Parallel(n_jobs=-1)]: Done 386 tasks      | elapsed:    3.9s
#
# building tree 389 of 500
# [Parallel(n_jobs=-1)]: Done 387 tasks      | elapsed:    3.9s
# building tree 390 of 500[Parallel(n_jobs=-1)]: Done 388 tasks      | elapsed:    3.9s
#
# building tree 391 of 500
# [Parallel(n_jobs=-1)]: Done 389 tasks      | elapsed:    3.9s
# building tree 392 of 500[Parallel(n_jobs=-1)]: Done 390 tasks      | elapsed:    4.0s
#
# building tree 393 of 500[Parallel(n_jobs=-1)]: Done 391 tasks      | elapsed:    4.0s
#
# building tree 394 of 500[Parallel(n_jobs=-1)]: Done 392 tasks      | elapsed:    4.0s
#
# building tree 395 of 500[Parallel(n_jobs=-1)]: Done 393 tasks      | elapsed:    4.0s
#
# building tree 396 of 500[Parallel(n_jobs=-1)]: Done 394 tasks      | elapsed:    4.0s
#
# building tree 397 of 500
# [Parallel(n_jobs=-1)]: Done 395 tasks      | elapsed:    4.0s
# building tree 398 of 500
# [Parallel(n_jobs=-1)]: Done 396 tasks      | elapsed:    4.0s
# building tree 399 of 500[Parallel(n_jobs=-1)]: Done 397 tasks      | elapsed:    4.1s
#
# building tree 400 of 500[Parallel(n_jobs=-1)]: Done 398 tasks      | elapsed:    4.1s
#
# building tree 401 of 500[Parallel(n_jobs=-1)]: Done 399 tasks      | elapsed:    4.1s
#
# building tree 402 of 500[Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:    4.1s
#
# building tree 403 of 500[Parallel(n_jobs=-1)]: Done 401 tasks      | elapsed:    4.1s
#
# building tree 404 of 500
# [Parallel(n_jobs=-1)]: Done 402 tasks      | elapsed:    4.1s
# building tree 405 of 500[Parallel(n_jobs=-1)]: Done 403 tasks      | elapsed:    4.1s
# building tree 406 of 500
# [Parallel(n_jobs=-1)]: Done 404 tasks      | elapsed:    4.1s
#
# building tree 407 of 500[Parallel(n_jobs=-1)]: Done 405 tasks      | elapsed:    4.1s
#
# building tree 408 of 500[Parallel(n_jobs=-1)]: Done 406 tasks      | elapsed:    4.1s
#
# building tree 409 of 500[Parallel(n_jobs=-1)]: Done 407 tasks      | elapsed:    4.1s
#
# building tree 410 of 500[Parallel(n_jobs=-1)]: Done 408 tasks      | elapsed:    4.1s
#
# building tree 411 of 500[Parallel(n_jobs=-1)]: Done 409 tasks      | elapsed:    4.2s
#
# building tree 412 of 500[Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed:    4.2s
#
# building tree 413 of 500[Parallel(n_jobs=-1)]: Done 411 tasks      | elapsed:    4.2s
#
# building tree 414 of 500[Parallel(n_jobs=-1)]: Done 412 tasks      | elapsed:    4.2s
#
# building tree 415 of 500[Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:    4.2s
#
# building tree 416 of 500
# [Parallel(n_jobs=-1)]: Done 414 tasks      | elapsed:    4.2s
# building tree 417 of 500
# [Parallel(n_jobs=-1)]: Done 415 tasks      | elapsed:    4.2s
# building tree 418 of 500[Parallel(n_jobs=-1)]: Done 416 tasks      | elapsed:    4.2s
#
# building tree 419 of 500
# [Parallel(n_jobs=-1)]: Done 417 tasks      | elapsed:    4.2s
# building tree 420 of 500[Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:    4.2s
#
# building tree 421 of 500[Parallel(n_jobs=-1)]: Done 419 tasks      | elapsed:    4.3s
#
# building tree 422 of 500
# [Parallel(n_jobs=-1)]: Done 420 tasks      | elapsed:    4.3s
# building tree 423 of 500
# [Parallel(n_jobs=-1)]: Done 421 tasks      | elapsed:    4.3s
# building tree 424 of 500[Parallel(n_jobs=-1)]: Done 422 tasks      | elapsed:    4.3s
#
# building tree 425 of 500[Parallel(n_jobs=-1)]: Done 423 tasks      | elapsed:    4.3s
# building tree 426 of 500[Parallel(n_jobs=-1)]: Done 424 tasks      | elapsed:    4.3s
#
#
# building tree 427 of 500[Parallel(n_jobs=-1)]: Done 425 tasks      | elapsed:    4.3s
# building tree 428 of 500[Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:    4.3s
#
#
# building tree 429 of 500[Parallel(n_jobs=-1)]: Done 427 tasks      | elapsed:    4.3s
#
# building tree 430 of 500[Parallel(n_jobs=-1)]: Done 428 tasks      | elapsed:    4.3s
#
# building tree 431 of 500[Parallel(n_jobs=-1)]: Done 429 tasks      | elapsed:    4.4s
#
# building tree 432 of 500[Parallel(n_jobs=-1)]: Done 430 tasks      | elapsed:    4.4s
#
# building tree 433 of 500[Parallel(n_jobs=-1)]: Done 431 tasks      | elapsed:    4.4s
#
# building tree 434 of 500
# [Parallel(n_jobs=-1)]: Done 432 tasks      | elapsed:    4.4s
# building tree 435 of 500[Parallel(n_jobs=-1)]: Done 433 tasks      | elapsed:    4.4s
#
# building tree 436 of 500[Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:    4.4s
#
# building tree 437 of 500[Parallel(n_jobs=-1)]: Done 435 tasks      | elapsed:    4.4s
#
# building tree 438 of 500[Parallel(n_jobs=-1)]: Done 436 tasks      | elapsed:    4.4s
#
# building tree 439 of 500[Parallel(n_jobs=-1)]: Done 437 tasks      | elapsed:    4.4s
#
# building tree 440 of 500[Parallel(n_jobs=-1)]: Done 438 tasks      | elapsed:    4.4s
#
# building tree 441 of 500[Parallel(n_jobs=-1)]: Done 439 tasks      | elapsed:    4.4s
#
# building tree 442 of 500[Parallel(n_jobs=-1)]: Done 440 tasks      | elapsed:    4.5s
#
# building tree 443 of 500[Parallel(n_jobs=-1)]: Done 441 tasks      | elapsed:    4.5s
#
# building tree 444 of 500[Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:    4.5s
#
# building tree 445 of 500[Parallel(n_jobs=-1)]: Done 443 tasks      | elapsed:    4.5s
#
# building tree 446 of 500[Parallel(n_jobs=-1)]: Done 444 tasks      | elapsed:    4.5s
#
# building tree 447 of 500[Parallel(n_jobs=-1)]: Done 445 tasks      | elapsed:    4.5s
#
# building tree 448 of 500[Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed:    4.5s
#
# building tree 449 of 500[Parallel(n_jobs=-1)]: Done 447 tasks      | elapsed:    4.5s
#
# building tree 450 of 500[Parallel(n_jobs=-1)]: Done 448 tasks      | elapsed:    4.5s
#
# building tree 451 of 500[Parallel(n_jobs=-1)]: Done 449 tasks      | elapsed:    4.5s
#
# building tree 452 of 500[Parallel(n_jobs=-1)]: Done 450 tasks      | elapsed:    4.6s
#
# building tree 453 of 500[Parallel(n_jobs=-1)]: Done 451 tasks      | elapsed:    4.6s
#
# building tree 454 of 500[Parallel(n_jobs=-1)]: Done 452 tasks      | elapsed:    4.6s
#
# building tree 455 of 500[Parallel(n_jobs=-1)]: Done 453 tasks      | elapsed:    4.6s
#
# building tree 456 of 500[Parallel(n_jobs=-1)]: Done 454 tasks      | elapsed:    4.6s
#
# building tree 457 of 500[Parallel(n_jobs=-1)]: Done 455 tasks      | elapsed:    4.6s
#
# building tree 458 of 500[Parallel(n_jobs=-1)]: Done 456 tasks      | elapsed:    4.6s
# building tree 459 of 500
# [Parallel(n_jobs=-1)]: Done 457 tasks      | elapsed:    4.6s
#
# building tree 460 of 500[Parallel(n_jobs=-1)]: Done 458 tasks      | elapsed:    4.6s
#
# building tree 461 of 500
# [Parallel(n_jobs=-1)]: Done 459 tasks      | elapsed:    4.6s
# building tree 462 of 500[Parallel(n_jobs=-1)]: Done 460 tasks      | elapsed:    4.7s
#
# building tree 463 of 500[Parallel(n_jobs=-1)]: Done 461 tasks      | elapsed:    4.7s
#
# building tree 464 of 500[Parallel(n_jobs=-1)]: Done 462 tasks      | elapsed:    4.7s
# building tree 465 of 500
#
# [Parallel(n_jobs=-1)]: Done 463 tasks      | elapsed:    4.7s
# building tree 466 of 500[Parallel(n_jobs=-1)]: Done 464 tasks      | elapsed:    4.7s
# building tree 467 of 500[Parallel(n_jobs=-1)]: Done 465 tasks      | elapsed:    4.7s
#
#
# building tree 468 of 500[Parallel(n_jobs=-1)]: Done 466 tasks      | elapsed:    4.7s
#
# building tree 469 of 500[Parallel(n_jobs=-1)]: Done 467 tasks      | elapsed:    4.7s
#
# building tree 470 of 500[Parallel(n_jobs=-1)]: Done 468 tasks      | elapsed:    4.8s
#
# building tree 471 of 500[Parallel(n_jobs=-1)]: Done 469 tasks      | elapsed:    4.8s
#
# building tree 472 of 500[Parallel(n_jobs=-1)]: Done 470 tasks      | elapsed:    4.8s
#
# building tree 473 of 500
# [Parallel(n_jobs=-1)]: Done 471 tasks      | elapsed:    4.8s
# building tree 474 of 500[Parallel(n_jobs=-1)]: Done 472 tasks      | elapsed:    4.8s
#
# building tree 475 of 500[Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:    4.8s
#
# building tree 476 of 500[Parallel(n_jobs=-1)]: Done 474 tasks      | elapsed:    4.8s
#
# building tree 477 of 500[Parallel(n_jobs=-1)]: Done 475 tasks      | elapsed:    4.8s
#
# building tree 478 of 500[Parallel(n_jobs=-1)]: Done 476 tasks      | elapsed:    4.8s
#
# building tree 479 of 500
# [Parallel(n_jobs=-1)]: Done 477 tasks      | elapsed:    4.8s
# building tree 480 of 500[Parallel(n_jobs=-1)]: Done 478 tasks      | elapsed:    4.9s
#
# building tree 481 of 500[Parallel(n_jobs=-1)]: Done 479 tasks      | elapsed:    4.9s
#
# building tree 482 of 500[Parallel(n_jobs=-1)]: Done 480 tasks      | elapsed:    4.9s
#
# building tree 483 of 500[Parallel(n_jobs=-1)]: Done 481 tasks      | elapsed:    4.9s
#
# building tree 484 of 500[Parallel(n_jobs=-1)]: Done 482 tasks      | elapsed:    4.9s
#
# building tree 485 of 500[Parallel(n_jobs=-1)]: Done 483 tasks      | elapsed:    4.9s
#
# building tree 486 of 500
# [Parallel(n_jobs=-1)]: Done 484 tasks      | elapsed:    4.9s
# building tree 487 of 500[Parallel(n_jobs=-1)]: Done 485 tasks      | elapsed:    4.9s
#
# building tree 488 of 500[Parallel(n_jobs=-1)]: Done 486 tasks      | elapsed:    4.9s
#
# building tree 489 of 500[Parallel(n_jobs=-1)]: Done 487 tasks      | elapsed:    4.9s
#
# building tree 490 of 500[Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:    5.0s
#
# building tree 491 of 500[Parallel(n_jobs=-1)]: Done 489 tasks      | elapsed:    5.0s
#
# building tree 492 of 500[Parallel(n_jobs=-1)]: Done 490 tasks      | elapsed:    5.0s
#
# building tree 493 of 500[Parallel(n_jobs=-1)]: Done 491 tasks      | elapsed:    5.0s
#
# building tree 494 of 500[Parallel(n_jobs=-1)]: Done 492 tasks      | elapsed:    5.0s
#
# building tree 495 of 500[Parallel(n_jobs=-1)]: Done 493 tasks      | elapsed:    5.0s
#
# building tree 496 of 500[Parallel(n_jobs=-1)]: Done 494 tasks      | elapsed:    5.0s
#
# building tree 497 of 500[Parallel(n_jobs=-1)]: Done 495 tasks      | elapsed:    5.0s
#
# building tree 498 of 500[Parallel(n_jobs=-1)]: Done 496 tasks      | elapsed:    5.0s
#
# building tree 499 of 500[Parallel(n_jobs=-1)]: Done 497 tasks      | elapsed:    5.1s
# building tree 500 of 500
#
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:    5.1s finished
# Model training complete and saved.

# %%
#Load the trained model
from joblib import load
filename = '/content/randomforest_depart_new.joblib'
rf = load(filename)

#Prepare the test data
print('Start to load test data for "Departed"...')
test_departed, features = get_features_departed(test, model=True)
print(test_departed.columns)  # To confirm the columns before proceeding
test_ready = test_departed.dropna(subset=features)  # Ensure data is clean

print('Test Data for "Departed" is ready...')

#Ensure you only select the relevant features for prediction
test_ready = test_ready[features]
test_ready = test_ready.rename(columns={'y_depart': 'y'})

y_test_actual = test_ready['y']
X_test = test_ready.drop('y', axis=1, errors='ignore')

#Make predictions
y_test_predicted_rf = rf.predict(X_test)

#Evaluate the model
print_metrics(y_test_actual, y_test_predicted_rf)
# Out:
# Start to load test data for "Departed"...
# created depart columns...
# merged depart statistics...
# Index(['REFERENCE#', 'CUSTOMER', 'SCHEDULED_ETA', 'SCHEDULED_ETD',
#        'ACTUAL_DEPART_DATE', 'ACTUAL_ARRIVAL_DATE', 'PORT_OF_LOAD',
#        'LOAD_COUNTRY', 'PORT_OF_DISCHARGE', 'DISCHARGE_COUNTRY',
#        'DESTINATION_LOC', 'DESTINATION_COUNTRY', 'CARRIER', 'holiday',
#        'y_depart', 'route', 'delay_d', 'delay_a', 'quarter', 'departure_day',
#        'late_departure', 'mean_all_departed', 'route_mean', 'schedule',
#        'quarter_mean'],
#       dtype='object')
# Test Data for "Departed" is ready...
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  48 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  50 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  51 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  52 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  53 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  54 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  55 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  56 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  57 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  58 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  59 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  60 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  61 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  62 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  63 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  64 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  65 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  66 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  67 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  68 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  69 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  70 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  71 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  72 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  73 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  74 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  75 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  76 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  77 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  78 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  79 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  80 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  81 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  82 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  83 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  84 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  85 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  86 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  87 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  88 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  89 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  90 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  91 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  92 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  93 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  94 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  95 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  96 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  97 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  98 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  99 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 100 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 101 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 102 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 103 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 104 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 105 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 106 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 107 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 108 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 109 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 110 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 111 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 112 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 113 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 114 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 115 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 116 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 117 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 118 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 119 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 120 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 121 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 122 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 123 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 124 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 125 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 126 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 127 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 128 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 129 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 130 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 131 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 132 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 133 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 134 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 135 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 136 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 137 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 138 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 139 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 140 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 141 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 142 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 143 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 144 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 145 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 146 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 147 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 148 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 149 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 150 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 151 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 152 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 153 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 154 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 155 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 156 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 157 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 158 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 159 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 160 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 161 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 162 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 163 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 164 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 165 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 166 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 167 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 168 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 169 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 170 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 171 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 172 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 173 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 174 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 175 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 176 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 177 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 178 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 179 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 180 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 181 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 182 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 183 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 185 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 186 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 187 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 188 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 189 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 190 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 191 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 192 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 193 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 194 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 195 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 196 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 197 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 198 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 199 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 200 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 201 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 202 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 203 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 204 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 205 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 206 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 207 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 208 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 209 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 210 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 211 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 212 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 213 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 214 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 215 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 216 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 217 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 218 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 219 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 220 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 221 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 222 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 223 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 224 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 225 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 226 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 227 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 228 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 229 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 230 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 231 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 232 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 233 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 234 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 235 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 236 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 237 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 238 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 239 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 240 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 241 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 242 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 243 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 244 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 245 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 246 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 247 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 248 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 249 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 250 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 251 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 252 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 253 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 255 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 256 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 257 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 258 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 259 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 260 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 261 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 262 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 263 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 264 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 265 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 266 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 267 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 268 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 269 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 270 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 271 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 272 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 273 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 274 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 275 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 276 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 277 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 278 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 279 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 280 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 281 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 282 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 283 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 284 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 285 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 286 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 287 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 288 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 289 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 290 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 291 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 292 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 293 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 294 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 295 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 296 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 297 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 298 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 299 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 300 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 301 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 302 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 303 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 304 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 305 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 306 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 307 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 308 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 309 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 310 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 311 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 312 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 313 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 314 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 315 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 316 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 317 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 318 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 319 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 320 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 321 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 322 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 323 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 324 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 325 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 326 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 327 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 328 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 329 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 330 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 331 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 332 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 333 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 334 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 335 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 336 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 337 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 338 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 339 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 340 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 341 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 342 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 343 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 344 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 345 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 346 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 347 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 348 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 349 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 350 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 351 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 352 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 353 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 354 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 355 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 356 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 357 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 358 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 359 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 360 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 361 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 362 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 363 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 364 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 365 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 366 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 367 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 368 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 369 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 370 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 371 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 372 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 373 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 374 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 375 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 376 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 377 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 378 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 379 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 380 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 381 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 382 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 383 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 384 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 385 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 386 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 387 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 388 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 389 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 390 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 391 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 392 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 393 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 394 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 395 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 396 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 397 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 398 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 399 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 400 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 401 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 402 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 403 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 404 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 405 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 406 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 407 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 408 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 409 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 410 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 411 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 412 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 413 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 414 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 415 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 416 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 417 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 418 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 419 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 420 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 421 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 422 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 423 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 424 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 425 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 426 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 427 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 428 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 429 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 430 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 431 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 432 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 433 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 434 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 435 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 436 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 437 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 438 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 439 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 440 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 441 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 442 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 443 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 444 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 445 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 446 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 447 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 448 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 449 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 450 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 451 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 452 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 453 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 454 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 455 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 456 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 457 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 458 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 459 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 460 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 461 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 462 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 463 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 464 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 465 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 466 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 467 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 468 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 469 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 470 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 471 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 472 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 473 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 474 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 475 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 476 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 477 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 478 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 479 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 480 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 481 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 482 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 483 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 484 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 485 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 486 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 487 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 488 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 489 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 490 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 491 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 492 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 493 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 494 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 495 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 496 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 497 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 500 out of 500 | elapsed:    0.3s finished
#     MAE    MAPE  RMSE    R2
# 0  5.71  0.1748  7.06  0.77

# %% [markdown]
# ### Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
from joblib import dump, load

# Load model data for "Departed"
print('Start to load model data for "Departed"...')
model_departed, features = get_features_departed(train, model=True)
print(model_departed.columns)  # Ensure this is before dropping NaNs
model_ready = model_departed.dropna(subset=features)

# Select relevant columns
model_ready = model_ready[features]

# Data preparation for model
model_ready = model_ready.rename(columns={'y_depart': 'y'})

X = model_ready.drop('y', axis=1)
y = model_ready['y']
trees = 500
depth = 5  # Preset depth for "Departed" model

# Train the boost model
print('Begin training boost model for "Departed"...')
boost_model = boost(depth=depth, trees=trees)

# Train the model
boost_model.fit(X, y)

# Save the trained model
filename = '/content/gradientboost_depart_new.joblib'
dump(boost_model, filename)

print('Boost model training complete and saved.')
# Out:
# Start to load model data for "Departed"...
# created depart columns...
# merged depart statistics...
# Index(['REFERENCE#', 'CUSTOMER', 'SCHEDULED_ETA', 'SCHEDULED_ETD',
#        'ACTUAL_DEPART_DATE', 'ACTUAL_ARRIVAL_DATE', 'PORT_OF_LOAD',
#        'LOAD_COUNTRY', 'PORT_OF_DISCHARGE', 'DISCHARGE_COUNTRY',
#        'DESTINATION_LOC', 'DESTINATION_COUNTRY', 'CARRIER', 'holiday',
#        'y_depart', 'route', 'delay_d', 'delay_a', 'quarter', 'departure_day',
#        'late_departure', 'mean_all_departed', 'route_mean', 'schedule',
#        'quarter_mean'],
#       dtype='object')
# Begin training boost model for "Departed"...
#       Iter       Train Loss   Remaining Time
#          1         160.2322           24.98s
#          2         157.9612           19.33s
#          3         155.7510           15.90s
#          4         153.6054           14.46s
#          5         151.4571           13.30s
#          6         149.2296           12.77s
#          7         147.0777           16.34s
#          8         144.9648           18.74s
#          9         142.8640           17.83s
#         10         140.7573           17.31s
#         11         138.8127           17.65s
#         12         136.9864           19.28s
#         13         135.2536           19.17s
#         14         133.3451           19.56s
#         15         131.5307           19.77s
#         16         129.7421           19.23s
#         17         127.9933           18.72s
#         18         126.2517           18.42s
#         19         124.5596           18.12s
#         20         123.0036           17.69s
#         21         121.4683           17.95s
#         22         119.7912           17.84s
#         23         118.2281           17.83s
#         24         116.6749           17.62s
#         25         115.1498           17.85s
#         26         113.7229           17.89s
#         27         112.2767           17.93s
#         28         110.8368           18.01s
#         29         109.3562           18.06s
#         30         107.9677           18.17s
#         31         106.6114           17.93s
#         32         105.2530           17.76s
#         33         103.9240           17.50s
#         34         102.6270           17.43s
#         35         101.3711           17.64s
#         36         100.0747           17.67s
#         37          98.8318           17.49s
#         38          97.6078           17.28s
#         39          96.4098           17.10s
#         40          95.2573           16.88s
#         41          94.0829           16.67s
#         42          92.9736           16.45s
#         43          91.8819           16.27s
#         44          90.7762           16.15s
#         45          89.7568           16.05s
#         46          88.7390           15.91s
#         47          87.7491           15.76s
#         48          86.7618           15.59s
#         49          85.7991           15.49s
#         50          84.8334           15.32s
#         51          83.9081           15.18s
#         52          82.9657           15.07s
#         53          82.0539           15.16s
#         54          81.1309           15.06s
#         55          80.2018           14.93s
#         56          79.3933           14.80s
#         57          78.5178           14.69s
#         58          77.7010           14.60s
#         59          76.8628           14.50s
#         60          76.0977           14.37s
#         61          75.3131           14.24s
#         62          74.5511           14.18s
#         63          73.7655           14.09s
#         64          72.9159           14.04s
#         65          72.1265           13.93s
#         66          71.3731           13.83s
#         67          70.6332           13.75s
#         68          69.9079           13.66s
#         69          69.2038           13.62s
#         70          68.5229           13.54s
#         71          67.8576           13.48s
#         72          67.2522           13.40s
#         73          66.5910           13.36s
#         74          65.9730           13.42s
#         75          65.3709           13.33s
#         76          64.7745           13.23s
#         77          64.1120           13.15s
#         78          63.5233           13.10s
#         79          62.9718           13.05s
#         80          62.3690           13.07s
#         81          61.7737           13.00s
#         82          61.2255           12.91s
#         83          60.6563           12.84s
#         84          60.1077           12.77s
#         85          59.5461           12.69s
#         86          59.0236           12.62s
#         87          58.4450           12.67s
#         88          57.9492           12.61s
#         89          57.4542           12.54s
#         90          56.9684           12.48s
#         91          56.4774           12.45s
#         92          56.0361           12.38s
#         93          55.5764           12.39s
#         94          55.0972           12.33s
#         95          54.6549           12.31s
#         96          54.1963           12.25s
#         97          53.7831           12.20s
#         98          53.3879           12.12s
#         99          52.9790           12.06s
#        100          52.5651           12.00s
#        101          52.1858           11.94s
#        102          51.8082           11.89s
#        103          51.3964           11.82s
#        104          51.0240           11.80s
#        105          50.6598           11.74s
#        106          50.2705           11.68s
#        107          49.8681           11.73s
#        108          49.4960           11.75s
#        109          49.1287           11.72s
#        110          48.7771           11.66s
#        111          48.4361           11.62s
#        112          48.0994           11.64s
#        113          47.7703           11.62s
#        114          47.4294           11.59s
#        115          47.1388           11.58s
#        116          46.8179           11.54s
#        117          46.4927           11.50s
#        118          46.1838           11.47s
#        119          45.8619           11.41s
#        120          45.5737           11.35s
#        121          45.2931           11.29s
#        122          45.0160           11.31s
#        123          44.7352           11.29s
#        124          44.4782           11.24s
#        125          44.2022           11.19s
#        126          43.9060           11.15s
#        127          43.6627           11.10s
#        128          43.3840           11.04s
#        129          43.0859           10.99s
#        130          42.8270           10.93s
#        131          42.5826           10.89s
#        132          42.3196           10.88s
#        133          42.0958           10.86s
#        134          41.8175           10.81s
#        135          41.6000           10.79s
#        136          41.3784           10.75s
#        137          41.1569           10.70s
#        138          40.9394           10.64s
#        139          40.7322           10.59s
#        140          40.5147           10.54s
#        141          40.2934           10.50s
#        142          40.0701           10.47s
#        143          39.8558           10.42s
#        144          39.6295           10.39s
#        145          39.4275           10.34s
#        146          39.2040           10.30s
#        147          38.9957           10.25s
#        148          38.7586           10.21s
#        149          38.5414           10.19s
#        150          38.3469           10.14s
#        151          38.1627           10.11s
#        152          37.9890           10.10s
#        153          37.8104           10.06s
#        154          37.6423           10.04s
#        155          37.4998           10.00s
#        156          37.3289            9.95s
#        157          37.1531            9.90s
#        158          36.9867            9.86s
#        159          36.8359            9.85s
#        160          36.6681            9.81s
#        161          36.5291            9.78s
#        162          36.3666            9.76s
#        163          36.1802            9.79s
#        164          36.0293            9.85s
#        165          35.8852            9.94s
#        166          35.7481            9.99s
#        167          35.5801           10.04s
#        168          35.4147           10.10s
#        169          35.2754           10.14s
#        170          35.1153           10.14s
#        171          34.9496           10.16s
#        172          34.8187           10.25s
#        173          34.6761           10.30s
#        174          34.5465           10.26s
#        175          34.4166           10.21s
#        176          34.3043           10.16s
#        177          34.1720           10.14s
#        178          34.0218           10.14s
#        179          33.8943           10.09s
#        180          33.7665           10.04s
#        181          33.6352            9.99s
#        182          33.5158            9.95s
#        183          33.3801            9.90s
#        184          33.2704            9.86s
#        185          33.1478            9.81s
#        186          33.0477            9.78s
#        187          32.9168            9.76s
#        188          32.8157            9.71s
#        189          32.7032            9.66s
#        190          32.5803            9.62s
#        191          32.5014            9.59s
#        192          32.4008            9.54s
#        193          32.2729            9.50s
#        194          32.1859            9.45s
#        195          32.0726            9.41s
#        196          31.9481            9.39s
#        197          31.8439            9.36s
#        198          31.7370            9.31s
#        199          31.6408            9.26s
#        200          31.5323            9.22s
#        201          31.4320            9.17s
#        202          31.3355            9.13s
#        203          31.2451            9.10s
#        204          31.1750            9.10s
#        205          31.0924            9.06s
#        206          31.0041            9.05s
#        207          30.9162            9.02s
#        208          30.8244            8.97s
#        209          30.7335            8.95s
#        210          30.6368            8.92s
#        211          30.5604            8.89s
#        212          30.4779            8.86s
#        213          30.4059            8.82s
#        214          30.3147            8.77s
#        215          30.2345            8.73s
#        216          30.1615            8.72s
#        217          30.0651            8.71s
#        218          29.9979            8.74s
#        219          29.9294            8.74s
#        220          29.8473            8.71s
#        221          29.7712            8.66s
#        222          29.7016            8.66s
#        223          29.6377            8.67s
#        224          29.5496            8.64s
#        225          29.4866            8.61s
#        226          29.4025            8.64s
#        227          29.3454            8.70s
#        228          29.2705            8.70s
#        229          29.2097            8.71s
#        230          29.1303            8.75s
#        231          29.0676            8.85s
#        232          29.0156            8.82s
#        233          28.9579            8.84s
#        234          28.9063            8.86s
#        235          28.8414            8.86s
#        236          28.7749            8.87s
#        237          28.7256            8.86s
#        238          28.6657            8.84s
#        239          28.6030            8.82s
#        240          28.5485            8.85s
#        241          28.4666            8.82s
#        242          28.4121            8.77s
#        243          28.3666            8.73s
#        244          28.3092            8.69s
#        245          28.2565            8.64s
#        246          28.2029            8.59s
#        247          28.1481            8.54s
#        248          28.0824            8.50s
#        249          28.0305            8.46s
#        250          27.9775            8.41s
#        251          27.8981            8.37s
#        252          27.8422            8.32s
#        253          27.7663            8.28s
#        254          27.7106            8.24s
#        255          27.6573            8.19s
#        256          27.6132            8.14s
#        257          27.5624            8.10s
#        258          27.5130            8.07s
#        259          27.4503            8.03s
#        260          27.4081            8.00s
#        261          27.3631            7.95s
#        262          27.3172            7.91s
#        263          27.2551            7.87s
#        264          27.2093            7.82s
#        265          27.1582            7.78s
#        266          27.1063            7.73s
#        267          27.0696            7.69s
#        268          27.0225            7.65s
#        269          26.9721            7.61s
#        270          26.9173            7.57s
#        271          26.8802            7.53s
#        272          26.8500            7.49s
#        273          26.8187            7.44s
#        274          26.7825            7.40s
#        275          26.7377            7.36s
#        276          26.6732            7.32s
#        277          26.6229            7.28s
#        278          26.5864            7.24s
#        279          26.5546            7.20s
#        280          26.5288            7.16s
#        281          26.4926            7.12s
#        282          26.4625            7.08s
#        283          26.4184            7.03s
#        284          26.3907            7.00s
#        285          26.3304            6.96s
#        286          26.2707            6.92s
#        287          26.2313            6.89s
#        288          26.1949            6.85s
#        289          26.1499            6.81s
#        290          26.1191            6.78s
#        291          26.0838            6.74s
#        292          26.0277            6.70s
#        293          25.9708            6.66s
#        294          25.9332            6.63s
#        295          25.8887            6.60s
#        296          25.8506            6.56s
#        297          25.8029            6.51s
#        298          25.7667            6.48s
#        299          25.7304            6.44s
#        300          25.6751            6.40s
#        301          25.6480            6.37s
#        302          25.5880            6.34s
#        303          25.5494            6.30s
#        304          25.5053            6.26s
#        305          25.4788            6.23s
#        306          25.4442            6.19s
#        307          25.4089            6.16s
#        308          25.3808            6.12s
#        309          25.3541            6.08s
#        310          25.3145            6.04s
#        311          25.2738            6.01s
#        312          25.2522            5.97s
#        313          25.2244            5.94s
#        314          25.1949            5.90s
#        315          25.1670            5.86s
#        316          25.1303            5.83s
#        317          25.0998            5.79s
#        318          25.0788            5.75s
#        319          25.0371            5.72s
#        320          24.9971            5.68s
#        321          24.9746            5.65s
#        322          24.9524            5.62s
#        323          24.9287            5.59s
#        324          24.8940            5.55s
#        325          24.8498            5.52s
#        326          24.8070            5.49s
#        327          24.7741            5.45s
#        328          24.7384            5.42s
#        329          24.7085            5.38s
#        330          24.6802            5.35s
#        331          24.6582            5.31s
#        332          24.6353            5.28s
#        333          24.6042            5.24s
#        334          24.5698            5.21s
#        335          24.5475            5.18s
#        336          24.5238            5.14s
#        337          24.4878            5.10s
#        338          24.4641            5.07s
#        339          24.4435            5.03s
#        340          24.4210            5.00s
#        341          24.3985            4.96s
#        342          24.3687            4.92s
#        343          24.3529            4.89s
#        344          24.3182            4.85s
#        345          24.2697            4.82s
#        346          24.2332            4.79s
#        347          24.1955            4.76s
#        348          24.1741            4.73s
#        349          24.1460            4.69s
#        350          24.1074            4.66s
#        351          24.0809            4.63s
#        352          24.0654            4.59s
#        353          24.0353            4.56s
#        354          24.0057            4.53s
#        355          23.9628            4.49s
#        356          23.9460            4.46s
#        357          23.9154            4.42s
#        358          23.8873            4.39s
#        359          23.8574            4.35s
#        360          23.8373            4.32s
#        361          23.8160            4.29s
#        362          23.7926            4.26s
#        363          23.7713            4.22s
#        364          23.7591            4.19s
#        365          23.7243            4.16s
#        366          23.6958            4.13s
#        367          23.6788            4.10s
#        368          23.6584            4.06s
#        369          23.6348            4.03s
#        370          23.5994            4.00s
#        371          23.5743            3.97s
#        372          23.5340            3.93s
#        373          23.5090            3.90s
#        374          23.4826            3.87s
#        375          23.4705            3.84s
#        376          23.4521            3.80s
#        377          23.4244            3.77s
#        378          23.4074            3.74s
#        379          23.3817            3.70s
#        380          23.3651            3.67s
#        381          23.3377            3.64s
#        382          23.3152            3.61s
#        383          23.2890            3.58s
#        384          23.2666            3.55s
#        385          23.2515            3.52s
#        386          23.2278            3.48s
#        387          23.2135            3.45s
#        388          23.1873            3.42s
#        389          23.1385            3.39s
#        390          23.1068            3.36s
#        391          23.0921            3.33s
#        392          23.0770            3.30s
#        393          23.0550            3.26s
#        394          23.0375            3.23s
#        395          23.0154            3.20s
#        396          22.9943            3.17s
#        397          22.9752            3.14s
#        398          22.9457            3.11s
#        399          22.9247            3.08s
#        400          22.9137            3.04s
#        401          22.8967            3.01s
#        402          22.8694            2.98s
#        403          22.8573            2.95s
#        404          22.8412            2.92s
#        405          22.8200            2.89s
#        406          22.8036            2.86s
#        407          22.7689            2.83s
#        408          22.7446            2.79s
#        409          22.7209            2.76s
#        410          22.6979            2.73s
#        411          22.6826            2.70s
#        412          22.6555            2.67s
#        413          22.6378            2.64s
#        414          22.6205            2.60s
#        415          22.5806            2.57s
#        416          22.5455            2.54s
#        417          22.5275            2.51s
#        418          22.5175            2.48s
#        419          22.5088            2.45s
#        420          22.4954            2.42s
#        421          22.4832            2.39s
#        422          22.4713            2.36s
#        423          22.4577            2.33s
#        424          22.4502            2.29s
#        425          22.4362            2.26s
#        426          22.4184            2.23s
#        427          22.3911            2.20s
#        428          22.3609            2.17s
#        429          22.3451            2.14s
#        430          22.3359            2.11s
#        431          22.3155            2.08s
#        432          22.3014            2.05s
#        433          22.2745            2.02s
#        434          22.2484            1.99s
#        435          22.2308            1.95s
#        436          22.2226            1.92s
#        437          22.2110            1.89s
#        438          22.1967            1.86s
#        439          22.1812            1.83s
#        440          22.1657            1.80s
#        441          22.1582            1.77s
#        442          22.1245            1.74s
#        443          22.1133            1.71s
#        444          22.0882            1.68s
#        445          22.0630            1.65s
#        446          22.0487            1.62s
#        447          22.0238            1.59s
#        448          22.0103            1.56s
#        449          22.0044            1.53s
#        450          21.9952            1.50s
#        451          21.9875            1.47s
#        452          21.9610            1.44s
#        453          21.9431            1.41s
#        454          21.9365            1.38s
#        455          21.9098            1.35s
#        456          21.8987            1.32s
#        457          21.8858            1.29s
#        458          21.8608            1.26s
#        459          21.8426            1.23s
#        460          21.8357            1.20s
#        461          21.8216            1.17s
#        462          21.8048            1.14s
#        463          21.7951            1.11s
#        464          21.7750            1.08s
#        465          21.7672            1.04s
#        466          21.7549            1.01s
#        467          21.7320            0.98s
#        468          21.7241            0.95s
#        469          21.7145            0.92s
#        470          21.6895            0.89s
#        471          21.6776            0.86s
#        472          21.6714            0.83s
#        473          21.6574            0.80s
#        474          21.6368            0.77s
#        475          21.6108            0.74s
#        476          21.5934            0.71s
#        477          21.5814            0.68s
#        478          21.5762            0.65s
#        479          21.5607            0.62s
#        480          21.5554            0.59s
#        481          21.5433            0.56s
#        482          21.5313            0.53s
#        483          21.5170            0.50s
#        484          21.4921            0.47s
#        485          21.4812            0.44s
#        486          21.4626            0.41s
#        487          21.4386            0.38s
#        488          21.4157            0.35s
#        489          21.4111            0.33s
#        490          21.4026            0.30s
#        491          21.3901            0.27s
#        492          21.3836            0.24s
#        493          21.3772            0.21s
#        494          21.3689            0.18s
#        495          21.3418            0.15s
#        496          21.3217            0.12s
#        497          21.3146            0.09s
#        498          21.2969            0.06s
#        499          21.2868            0.03s
#        500          21.2703            0.00s
# Boost model training complete and saved.

# %%
# Load the trained model
filename = '/content/gradientboost_depart_new.joblib'
boost_model_loaded = load(filename)

# Prepare the test data
print('Start to load test data for "Departed"...')
test_departed, features = get_features_departed(test, model=True)
test_ready = test_departed.dropna(subset=features)  # Ensure data is clean

# Ensure you only select the relevant features for prediction
test_ready = test_ready[features]
test_ready = test_ready.rename(columns={'y_depart': 'y'})

y_test_actual = test_ready['y']
X_test = test_ready.drop('y', axis=1, errors='ignore')

# Make predictions
y_test_predicted_boost = boost_model_loaded.predict(X_test)

# Evaluate the model
print_metrics(y_test_actual, y_test_predicted_boost)
# Out:
# Start to load test data for "Departed"...
# created depart columns...
# merged depart statistics...
#     MAE    MAPE  RMSE    R2
# 0  5.69  0.1843  7.13  0.77

# %% [markdown]
# ### Report Generation

# %%
test
# Out:
#                     REFERENCE#  CUSTOMER SCHEDULED_ETA SCHEDULED_ETD  \
# 39       6346898550BMOU4409690       250    2022-12-26    2022-11-05
# 44       6346898550GESU6822200       250    2022-12-26    2022-11-05
# 67        292779362MNBU4369536       250    2023-01-14    2022-12-11
# 233       292779558MSKU9481073       250    2023-01-28    2022-12-27
# 238    143266062645EITU9228778       250    2023-01-06    2022-12-11
# ...                        ...       ...           ...           ...
# 50113    6348619971CSNU6448728       250    2023-01-22    2022-12-08
# 50146    2710078851OOLU7694214      3294    2023-01-10    2022-12-11
# 50155    6347416312CSNU4080719       250    2023-01-01    2022-11-19
# 50169    6348619592TCKU6497929       250    2023-01-22    2022-12-08
# 50263    6348620531CCLU7825617       250    2023-01-22    2022-12-08
#
#       ACTUAL_DEPART_DATE ACTUAL_ARRIVAL_DATE PORT_OF_LOAD LOAD_COUNTRY  \
# 39            2022-11-07          2023-01-05        CNFOC           CN
# 44            2022-11-07          2023-01-05        CNFOC           CN
# 67            2022-12-12          2023-01-15        CNTAO           CN
# 233           2022-12-28          2023-01-30        CNTAO           CN
# 238           2022-12-11          2023-01-07        CNNGB           CN
# ...                  ...                 ...          ...          ...
# 50113         2022-12-09          2023-01-26        CNFOC           CN
# 50146         2022-12-11          2023-01-13        CNYTN           CN
# 50155         2022-11-21          2023-01-07        CNFOC           CN
# 50169         2022-12-09          2023-01-26        CNFOC           CN
# 50263         2022-12-09          2023-01-26        CNFOC           CN
#
#       PORT_OF_DISCHARGE DISCHARGE_COUNTRY DESTINATION_LOC DESTINATION_COUNTRY  \
# 39                USSAV                US           USSAV                  US
# 44                USSAV                US           USSAV                  US
# 67                USSEA                US           USSEA                  US
# 233               USSEA                US           USSEA                  US
# 238               USTIW                US           USTIW                  US
# ...                 ...               ...             ...                 ...
# 50113             USORF                US           USORF                  US
# 50146             USNYC                US            CXMI                  US
# 50155             USORF                US           USORF                  US
# 50169             USORF                US           USORF                  US
# 50263             USORF                US           USORF                  US
#
#       CARRIER  holiday  y_depart  route  delay_d  delay_a  quarter  \
# 39       COSU        0        59     59        2       10        4
# 44       COSU        0        59     59        2       10        4
# 67       MAEU        0        34     34        1        1        4
# 233      MAEU        0        33     33        1        2        4
# 238      EGLV        0        27     27        0        1        4
# ...       ...      ...       ...    ...      ...      ...      ...
# 50113    COSU        0        48     48        1        4        4
# 50146    OOLU        0        33     33        0        3        4
# 50155    COSU        0        47     47        2        6        4
# 50169    COSU        0        48     48        1        4        4
# 50263    COSU        0        48     48        1        4        4
#
#       departure_day
# 39           Monday
# 44           Monday
# 67           Monday
# 233       Wednesday
# 238          Sunday
# ...             ...
# 50113        Friday
# 50146        Sunday
# 50155        Monday
# 50169        Friday
# 50263        Friday
#
# [2709 rows x 20 columns]

# %%
test = test.reset_index(drop=True)
test
# Out:
#                    REFERENCE#  CUSTOMER SCHEDULED_ETA SCHEDULED_ETD  \
# 0       6346898550BMOU4409690       250    2022-12-26    2022-11-05
# 1       6346898550GESU6822200       250    2022-12-26    2022-11-05
# 2        292779362MNBU4369536       250    2023-01-14    2022-12-11
# 3        292779558MSKU9481073       250    2023-01-28    2022-12-27
# 4     143266062645EITU9228778       250    2023-01-06    2022-12-11
# ...                       ...       ...           ...           ...
# 2704    6348619971CSNU6448728       250    2023-01-22    2022-12-08
# 2705    2710078851OOLU7694214      3294    2023-01-10    2022-12-11
# 2706    6347416312CSNU4080719       250    2023-01-01    2022-11-19
# 2707    6348619592TCKU6497929       250    2023-01-22    2022-12-08
# 2708    6348620531CCLU7825617       250    2023-01-22    2022-12-08
#
#      ACTUAL_DEPART_DATE ACTUAL_ARRIVAL_DATE PORT_OF_LOAD LOAD_COUNTRY  \
# 0            2022-11-07          2023-01-05        CNFOC           CN
# 1            2022-11-07          2023-01-05        CNFOC           CN
# 2            2022-12-12          2023-01-15        CNTAO           CN
# 3            2022-12-28          2023-01-30        CNTAO           CN
# 4            2022-12-11          2023-01-07        CNNGB           CN
# ...                 ...                 ...          ...          ...
# 2704         2022-12-09          2023-01-26        CNFOC           CN
# 2705         2022-12-11          2023-01-13        CNYTN           CN
# 2706         2022-11-21          2023-01-07        CNFOC           CN
# 2707         2022-12-09          2023-01-26        CNFOC           CN
# 2708         2022-12-09          2023-01-26        CNFOC           CN
#
#      PORT_OF_DISCHARGE DISCHARGE_COUNTRY DESTINATION_LOC DESTINATION_COUNTRY  \
# 0                USSAV                US           USSAV                  US
# 1                USSAV                US           USSAV                  US
# 2                USSEA                US           USSEA                  US
# 3                USSEA                US           USSEA                  US
# 4                USTIW                US           USTIW                  US
# ...                ...               ...             ...                 ...
# 2704             USORF                US           USORF                  US
# 2705             USNYC                US            CXMI                  US
# 2706             USORF                US           USORF                  US
# 2707             USORF                US           USORF                  US
# 2708             USORF                US           USORF                  US
#
#      CARRIER  holiday  y_depart  route  delay_d  delay_a  quarter  \
# 0       COSU        0        59     59        2       10        4
# 1       COSU        0        59     59        2       10        4
# 2       MAEU        0        34     34        1        1        4
# 3       MAEU        0        33     33        1        2        4
# 4       EGLV        0        27     27        0        1        4
# ...      ...      ...       ...    ...      ...      ...      ...
# 2704    COSU        0        48     48        1        4        4
# 2705    OOLU        0        33     33        0        3        4
# 2706    COSU        0        47     47        2        6        4
# 2707    COSU        0        48     48        1        4        4
# 2708    COSU        0        48     48        1        4        4
#
#      departure_day
# 0           Monday
# 1           Monday
# 2           Monday
# 3        Wednesday
# 4           Sunday
# ...            ...
# 2704        Friday
# 2705        Sunday
# 2706        Monday
# 2707        Friday
# 2708        Friday
#
# [2709 rows x 20 columns]

# %%
test_ready
# Out:
#       quarter  mean_all_departed  route_mean  late_departure  schedule  \
# 0           4              65.59        65.3               1      65.3
# 1           4              65.59        65.3               1      65.3
# 2           4              23.09        24.8               1      24.8
# 3           4              23.09        24.8               1      24.8
# 4           4              27.24        26.0               0      26.0
# ...       ...                ...         ...             ...       ...
# 2704        4              63.32        65.1               1      65.1
# 2705        4              43.40        43.8               0      43.8
# 2706        4              63.32        65.1               1      65.1
# 2707        4              63.32        65.1               1      65.1
# 2708        4              63.32        65.1               1      65.1
#
#       delay_a  delay_d   y
# 0          10        2  59
# 1          10        2  59
# 2           1        1  34
# 3           2        1  33
# 4           1        0  27
# ...       ...      ...  ..
# 2704        4        1  48
# 2705        3        0  33
# 2706        6        2  47
# 2707        4        1  48
# 2708        4        1  48
#
# [2659 rows x 8 columns]

# %%
missing_indices = set(test.index) - set(test_ready.index)
print(f"Missing indices: {missing_indices}")
# Out:
# Missing indices: {390, 136, 265, 392, 393, 649, 650, 2699, 399, 1296, 405, 406, 407, 2201, 2202, 1055, 1057, 930, 1827, 297, 1324, 2609, 307, 1205, 950, 567, 2615, 318, 2622, 324, 325, 330, 331, 205, 1486, 336, 338, 729, 1626, 1115, 2651, 605, 2652, 2271, 1379, 359, 2283, 2412, 1017, 1018}

# %%
report_df = pd.DataFrame({
    'ACTUAL_TRANSIT_TIME': y_test_actual,
    'BOOST_PREDICTED_TRANSIT_TIME': y_test_predicted_boost,
})

for column in test.columns:
    if column not in missing_indices:
        report_df[column] = test[column]

report_df.drop(columns=['holiday','y_depart','route','delay_d','delay_a','quarter','departure_day'], inplace=True)
report_df.to_csv('/content/drive/MyDrive/report_df.csv', encoding='utf-8')
report_df
# Out:
#       ACTUAL_TRANSIT_TIME  BOOST_PREDICTED_TRANSIT_TIME  \
# 0                      59                     59.561170
# 1                      59                     59.561170
# 2                      34                     20.563453
# 3                      33                     20.727706
# 4                      27                     25.480907
# ...                   ...                           ...
# 2704                   48                     61.607531
# 2705                   33                     36.236005
# 2706                   47                     60.962591
# 2707                   48                     61.607531
# 2708                   48                     61.607531
#
#                    REFERENCE#  CUSTOMER SCHEDULED_ETA SCHEDULED_ETD  \
# 0       6346898550BMOU4409690       250    2022-12-26    2022-11-05
# 1       6346898550GESU6822200       250    2022-12-26    2022-11-05
# 2        292779362MNBU4369536       250    2023-01-14    2022-12-11
# 3        292779558MSKU9481073       250    2023-01-28    2022-12-27
# 4     143266062645EITU9228778       250    2023-01-06    2022-12-11
# ...                       ...       ...           ...           ...
# 2704    6348619971CSNU6448728       250    2023-01-22    2022-12-08
# 2705    2710078851OOLU7694214      3294    2023-01-10    2022-12-11
# 2706    6347416312CSNU4080719       250    2023-01-01    2022-11-19
# 2707    6348619592TCKU6497929       250    2023-01-22    2022-12-08
# 2708    6348620531CCLU7825617       250    2023-01-22    2022-12-08
#
#      ACTUAL_DEPART_DATE ACTUAL_ARRIVAL_DATE PORT_OF_LOAD LOAD_COUNTRY  \
# 0            2022-11-07          2023-01-05        CNFOC           CN
# 1            2022-11-07          2023-01-05        CNFOC           CN
# 2            2022-12-12          2023-01-15        CNTAO           CN
# 3            2022-12-28          2023-01-30        CNTAO           CN
# 4            2022-12-11          2023-01-07        CNNGB           CN
# ...                 ...                 ...          ...          ...
# 2704         2022-12-09          2023-01-26        CNFOC           CN
# 2705         2022-12-11          2023-01-13        CNYTN           CN
# 2706         2022-11-21          2023-01-07        CNFOC           CN
# 2707         2022-12-09          2023-01-26        CNFOC           CN
# 2708         2022-12-09          2023-01-26        CNFOC           CN
#
#      PORT_OF_DISCHARGE DISCHARGE_COUNTRY DESTINATION_LOC DESTINATION_COUNTRY  \
# 0                USSAV                US           USSAV                  US
# 1                USSAV                US           USSAV                  US
# 2                USSEA                US           USSEA                  US
# 3                USSEA                US           USSEA                  US
# 4                USTIW                US           USTIW                  US
# ...                ...               ...             ...                 ...
# 2704             USORF                US           USORF                  US
# 2705             USNYC                US            CXMI                  US
# 2706             USORF                US           USORF                  US
# 2707             USORF                US           USORF                  US
# 2708             USORF                US           USORF                  US
#
#      CARRIER
# 0       COSU
# 1       COSU
# 2       MAEU
# 3       MAEU
# 4       EGLV
# ...      ...
# 2704    COSU
# 2705    OOLU
# 2706    COSU
# 2707    COSU
# 2708    COSU
#
# [2659 rows x 15 columns]

# %% [markdown]
# ### Neural Nets

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# Assuming get_features_departed and print_metrics are defined as before
print('Start to load model data for "Departed"...')
model_departed, features = get_features_departed(train, model=True)
print(model_departed.columns)
model_ready = model_departed.dropna(subset=features)

# Select relevant columns
model_ready = model_ready[features]

# Data preparation for the model
X = model_ready.drop('y_depart', axis=1)
y = model_ready['y_depart']

# Scaling features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Splitting the dataset for training and validation
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min')

# Initialize and train the neural network
print('Begin training neural network for "Departed"...')
model = neural_net(pd.DataFrame(X_scaled, columns=X.columns), neurons=10)

# Train the model
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, callbacks=[early_stopping], verbose=2)

# Save the trained model
model.save('/content/neural_network_depart_new.h5')

print('Neural network model training complete and saved.')
# Out:
# Start to load model data for "Departed"...
# created depart columns...
# merged depart statistics...
# Index(['REFERENCE#', 'CUSTOMER', 'SCHEDULED_ETA', 'SCHEDULED_ETD',
#        'ACTUAL_DEPART_DATE', 'ACTUAL_ARRIVAL_DATE', 'PORT_OF_LOAD',
#        'LOAD_COUNTRY', 'PORT_OF_DISCHARGE', 'DISCHARGE_COUNTRY',
#        'DESTINATION_LOC', 'DESTINATION_COUNTRY', 'CARRIER', 'holiday',
#        'y_depart', 'route', 'delay_d', 'delay_a', 'quarter', 'departure_day',
#        'late_departure', 'mean_all_departed', 'route_mean', 'schedule',
#        'quarter_mean'],
#       dtype='object')
# Begin training neural network for "Departed"...
# Epoch 1/100
# 1173/1173 - 4s - loss: 432.5629 - mape: 54.1689 - mae: 16.2992 - val_loss: 81.6903 - val_mape: 25.9825 - val_mae: 7.1147 - 4s/epoch - 4ms/step
# Epoch 2/100
# 1173/1173 - 2s - loss: 151.7066 - mape: 33.1949 - mae: 9.5229 - val_loss: 59.2025 - val_mape: 20.0827 - val_mae: 5.8243 - 2s/epoch - 2ms/step
# Epoch 3/100
# 1173/1173 - 2s - loss: 139.0106 - mape: 30.5209 - mae: 9.0074 - val_loss: 59.7219 - val_mape: 19.5326 - val_mae: 5.7912 - 2s/epoch - 2ms/step
# Epoch 4/100
# 1173/1173 - 2s - loss: 127.1562 - mape: 29.1044 - mae: 8.6043 - val_loss: 54.6594 - val_mape: 19.6727 - val_mae: 5.5954 - 2s/epoch - 2ms/step
# Epoch 5/100
# 1173/1173 - 2s - loss: 118.5495 - mape: 28.2332 - mae: 8.2746 - val_loss: 52.4381 - val_mape: 20.2231 - val_mae: 5.5445 - 2s/epoch - 2ms/step
# Epoch 6/100
# 1173/1173 - 2s - loss: 110.6632 - mape: 27.6631 - mae: 7.9951 - val_loss: 57.4763 - val_mape: 20.3767 - val_mae: 5.7098 - 2s/epoch - 2ms/step
# Epoch 7/100
# 1173/1173 - 3s - loss: 105.4081 - mape: 27.7174 - mae: 7.8284 - val_loss: 57.2033 - val_mape: 21.2054 - val_mae: 5.7232 - 3s/epoch - 3ms/step
# Epoch 8/100
# 1173/1173 - 2s - loss: 101.6806 - mape: 27.7681 - mae: 7.7030 - val_loss: 53.1909 - val_mape: 21.9516 - val_mae: 5.6168 - 2s/epoch - 2ms/step
# Epoch 9/100
# 1173/1173 - 2s - loss: 100.9465 - mape: 27.8741 - mae: 7.6769 - val_loss: 55.2594 - val_mape: 21.8161 - val_mae: 5.6888 - 2s/epoch - 2ms/step
# Epoch 10/100
# 1173/1173 - 2s - loss: 99.5372 - mape: 27.8105 - mae: 7.6445 - val_loss: 57.3490 - val_mape: 21.6791 - val_mae: 5.7589 - 2s/epoch - 2ms/step
# Epoch 11/100
# 1173/1173 - 2s - loss: 97.8799 - mape: 27.4647 - mae: 7.5598 - val_loss: 54.0744 - val_mape: 22.2518 - val_mae: 5.6742 - 2s/epoch - 2ms/step
# Epoch 12/100
# 1173/1173 - 3s - loss: 97.1625 - mape: 27.5287 - mae: 7.5438 - val_loss: 56.7795 - val_mape: 21.8585 - val_mae: 5.7481 - 3s/epoch - 2ms/step
# Epoch 13/100
# 1173/1173 - 4s - loss: 95.8178 - mape: 27.2442 - mae: 7.4667 - val_loss: 56.3011 - val_mape: 22.0024 - val_mae: 5.7425 - 4s/epoch - 3ms/step
# Epoch 14/100
# 1173/1173 - 2s - loss: 93.1220 - mape: 26.9671 - mae: 7.3803 - val_loss: 55.9435 - val_mape: 22.0122 - val_mae: 5.7352 - 2s/epoch - 2ms/step
# Epoch 15/100
# 1173/1173 - 2s - loss: 93.2810 - mape: 26.8971 - mae: 7.3732 - val_loss: 54.7296 - val_mape: 22.2634 - val_mae: 5.7024 - 2s/epoch - 2ms/step
# Epoch 15: early stopping
# Neural network model training complete and saved.
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the trained model
from tensorflow.keras.models import load_model

model_loaded = load_model('/content/neural_network_depart_new.h5')

# Prepare the test data (similar steps as before)
print('Start to load test data for "Departed"...')
test_departed, features = get_features_departed(test, model=True)
test_ready = test_departed.dropna(subset=features)

# Ensure you only select the relevant features for prediction
X_test = test_ready[features]
X_test = X_test.drop('y_depart', axis=1, errors='ignore')

# Scaling the test features
X_test_scaled = scaler.transform(X_test)

# Make predictions
y_test_predicted_nn = model_loaded.predict(X_test_scaled)

# Evaluate the model (You will need to adapt or create a print_metrics function suitable for regression metrics)
print_metrics(y_test_actual, y_test_predicted_nn.flatten())  # Assuming y_test_actual is defined and print_metrics is adapted for regression
# Out:
# Start to load test data for "Departed"...
# created depart columns...
# merged depart statistics...
# 84/84 [==============================] - 0s 3ms/step
#     MAE    MAPE  RMSE    R2
# 0  5.34  0.1688  6.87  0.64

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from joblib import dump, load

# Definition of multinomial logistic regression function
def multinomial_logistic_regression(C=1.0, solver='lbfgs', max_iter=10000, random_state=35):
    model = LogisticRegression(multi_class='multinomial',
                               C=C,
                               solver=solver,
                               max_iter=max_iter,
                               random_state=random_state)
    return model

# Load model data for "Departed"
print('Start to load model data for "Departed"...')
model_departed, features = get_features_departed(train, model=True)
print(model_departed.columns)  # Ensure this is before dropping NaNs
model_ready = model_departed.dropna(subset=features)

# Select relevant columns
model_ready = model_ready[features]

# Data preparation for model
model_ready = model_ready.rename(columns={'y_depart': 'y'})

X = model_ready.drop('y', axis=1)
y = model_ready['y']

# Initialize the multinomial logistic regression model
print('Begin training multinomial logistic regression model for "Departed"...')
logistic_model = multinomial_logistic_regression(C=1.0, solver='lbfgs', max_iter=10000)

# Train the model
logistic_model.fit(X, y)

# Save the trained model
filename = '/content/multinomial_logreg_departed.joblib'
dump(logistic_model, filename)

print('Multinomial logistic regression model training complete and saved.')
# Out:
# Start to load model data for "Departed"...
# created depart columns...
# merged depart statistics...
# Index(['REFERENCE#', 'CUSTOMER', 'SCHEDULED_ETA', 'SCHEDULED_ETD',
#        'ACTUAL_DEPART_DATE', 'ACTUAL_ARRIVAL_DATE', 'PORT_OF_LOAD',
#        'LOAD_COUNTRY', 'PORT_OF_DISCHARGE', 'DISCHARGE_COUNTRY',
#        'DESTINATION_LOC', 'DESTINATION_COUNTRY', 'CARRIER', 'holiday',
#        'y_depart', 'route', 'delay_d', 'delay_a', 'quarter', 'departure_day',
#        'late_departure', 'mean_all_departed', 'route_mean', 'schedule',
#        'quarter_mean'],
#       dtype='object')
# Begin training multinomial logistic regression model for "Departed"...
# Multinomial logistic regression model training complete and saved.
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Load the trained model
filename = '/content/multinomial_logreg_departed.joblib'
logistic_model_loaded = load(filename)

# Prepare the test data
print('Start to load test data for "Departed"...')
test_departed, features = get_features_departed(test, model=True)
test_ready = test_departed.dropna(subset=features)  # Ensure data is clean

# Ensure you only select the relevant features for prediction
test_ready = test_ready[features]
test_ready = test_ready.rename(columns={'y_depart': 'y'})

y_test_actual = test_ready['y']
X_test = test_ready.drop('y', axis=1, errors='ignore')

# Make predictions
y_test_predicted_logistic = logistic_model_loaded.predict(X_test)

# Evaluate the model
print_metrics(y_test_actual, y_test_predicted_logistic)
# Out:
# Start to load test data for "Departed"...
# created depart columns...
# merged depart statistics...
#     MAE   MAPE  RMSE    R2
# 0  7.34  0.251  9.33  0.69

# %% [markdown]
# ## Model Performances
#
# The performance of four regression models - Random Forest Regressor, Gradient Boosting Regressor, Neural Nets, and Logistic Regression - is compared below based on several metrics: Mean Absolute Error (MAE), Mean Absolute Percentage Error (MAPE), Root Mean Square Error (RMSE), and the R-squared (R2) value.
#
# | Model                       | MAE  | MAPE   | RMSE | R2   |
# |-----------------------------|------|--------|------|------|
# | Random Forest Regressor     | 5.71 | 0.1748 | 7.06 | 0.77 |
# | Gradient Boosting Regressor | 5.55 | 0.18   | 7.01 | 0.78 |
# | Neural Nets                 | 5.34 | 0.1688 | 6.87 | 0.64 |
# | Logistic Regression         | 7.34 | 0.251  | 9.33 | 0.69 |
#
# ## Analysis
#
# Among the evaluated models, the **Gradient Boosting Regressor** exhibits the best balance of performance across all metrics, with the lowest MAE and RMSE, and the highest R2 score, indicating a high level of accuracy and model fit to the data. However, the Neural Nets model shows a competitive performance, particularly in terms of MAE and MAPE, suggesting it might be more robust to outliers in certain scenarios despite its lower R2 score, which indicates a poorer fit overall compared to Gradient Boosting Regressor.
#
# The Logistic Regression model, on the other hand, has the highest errors (MAE and RMSE) and the highest MAPE, which suggests that it may not be as well suited for the dataset or the specific regression task compared to the other models.
#
# ## Next Steps
#
# To further improve model performance, the following steps are recommended:
#
# 1. **Feature Engineering:** Explore additional features or transformations that could improve model predictive power.
# 2. **Hyperparameter Tuning:** For the models with promising results, such as Gradient Boosting and Neural Nets, more extensive hyperparameter tuning could yield better performance.
# 3. **Cross-validation:** Implementing cross-validation can provide a more robust estimate of model performance across different subsets of the data.
# 4. **Ensemble Methods:** Combining the predictions from multiple models could lead to improved accuracy and robustness over individual model predictions.

# %% [markdown]
# ### Streamlit App Code

# %%
# !pip install pydeck
# Out:
# Requirement already satisfied: pydeck in /usr/local/lib/python3.10/dist-packages (0.8.1b0)
# Requirement already satisfied: jinja2>=2.10.1 in /usr/local/lib/python3.10/dist-packages (from pydeck) (3.1.3)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.10/dist-packages (from pydeck) (1.25.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.10.1->pydeck) (2.1.5)

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import numpy as np
import joblib
from datetime import datetime
from datetime import timedelta
import pydeck as pdk
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime


# Load the dataset with port coordinates
ports_coords = pd.read_excel('/content/drive/MyDrive/port_coordinates.xlsx')

# Function to get coordinates by port code
def get_port_coords(port_code):
    row = ports_coords[ports_coords['Port Code'] == port_code].iloc[0]
    return [row['Longitude'], row['Latitude']]

# Assuming precomputed statistics and historical delays are loaded here
chinese_holidays = pd.read_csv('/content/drive/MyDrive/chinese_holidays_complete.csv', sep=',', encoding='utf-8')
chinese_holidays['date'] = pd.to_datetime(chinese_holidays['date'])
# Load other precomputed statistics and historical delays as necessary
# stat_route_y, stat_route, stat_schedule, stat_quarter, historical_delays
stat_route_y = pd.read_csv('/content/drive/MyDrive/stat_route_y.csv')
stat_route = pd.read_csv('/content/drive/MyDrive/stat_route.csv')
stat_schedule = pd.read_csv('/content/drive/MyDrive/stat_schedule.csv')
stat_quarter = pd.read_csv('/content/drive/MyDrive/stat_quarter.csv')
historical_delays = pd.read_csv('/content/drive/MyDrive/historical_delays.csv')
new_df = pd.read_csv('/content/drive/MyDrive/new_df.csv')

# Define functions for preparing model input

def fetch_precomputed_statistics(carrier, original_port, final_port, departure_day_num, quarter, stat_route_y, stat_route, stat_schedule, stat_quarter):
    try:
        filtered_route_y = stat_route_y[(stat_route_y['CARRIER'] == carrier) &
                                        (stat_route_y['PORT_OF_LOAD'] == original_port) &
                                        (stat_route_y['PORT_OF_DISCHARGE'] == final_port)]
        if filtered_route_y.empty:
            mean_all_departed = 0  # Default or error value
        else:
            mean_all_departed = filtered_route_y['mean_all_departed'].values[0]

        filtered_route = stat_route[(stat_route['CARRIER'] == carrier) &
                                    (stat_route['PORT_OF_LOAD'] == original_port) &
                                    (stat_route['PORT_OF_DISCHARGE'] == final_port)]
        if filtered_route.empty:
            route_mean = 0  # Default or error value
        else:
            route_mean = filtered_route['route_mean'].values[0]

        filtered_schedule = stat_schedule[(stat_schedule['CARRIER'] == carrier) &
                                          (stat_schedule['PORT_OF_LOAD'] == original_port) &
                                          (stat_schedule['PORT_OF_DISCHARGE'] == final_port) &
                                          (stat_schedule['departure_day'] == str(departure_day_num))]
        if filtered_schedule.empty:
            schedule = 0  # Default or error value
        else:
            schedule = filtered_schedule['schedule'].values[0]

        filtered_quarter = stat_quarter[stat_quarter['quarter'] == quarter]
        if filtered_quarter.empty:
            quarter_mean = 0  # Default or error value
        else:
            quarter_mean = filtered_quarter['quarter_mean'].values[0]

        return mean_all_departed, route_mean, schedule, quarter_mean

    except Exception as e:
        print(f"An error occurred: {e}")
        # Return default or error values
        return 0, 0, 0, 0

def estimate_delays(carrier, original_port, final_port, quarter, historical_delays):
    try:
        filtered_delays = historical_delays[(historical_delays['CARRIER'] == carrier) &
                                            (historical_delays['quarter'] == quarter)]

        if filtered_delays.empty:
            # Set default values if no records match the filter
            late_departure_estimate = 0  # Default or error value for late departure probability
            delay_a_estimate = 0  # Default or error value for average arrival delay
            delay_d_estimate = 0  # Default or error value for average departure delay
        else:
            # Calculate mean values from the filtered DataFrame
            late_departure_estimate = filtered_delays['late_departure_prob'].mean()
            delay_a_estimate = filtered_delays['average_arrival_delay'].mean()
            delay_d_estimate = filtered_delays['average_departure_delay'].mean()

        return late_departure_estimate, delay_a_estimate, delay_d_estimate

    except Exception as e:
        print(f"An error occurred: {e}")
        # Return default or error values in case of an exception
        return 0, 0, 0


def prepare_model_input(carrier, original_port, final_port, eta, etd):
    eta = pd.to_datetime(eta)
    etd = pd.to_datetime(etd)
    quarter = etd.quarter
    holiday = 1 if etd in chinese_holidays['date'].values else 0
    departure_day = etd.day_name()
    day_to_num = {'Monday': 1, 'Tuesday': 2, 'Wednesday': 3, 'Thursday': 4, 'Friday': 5, 'Saturday': 6, 'Sunday': 7}
    departure_day_num = day_to_num.get(departure_day, 0)

    mean_all_departed, route_mean, schedule, quarter_mean = fetch_precomputed_statistics(carrier, original_port, final_port, departure_day_num, quarter, stat_route_y, stat_route, stat_schedule, stat_quarter)
    late_departure_estimate, delay_a_estimate, delay_d_estimate = estimate_delays(carrier, original_port, final_port, quarter, historical_delays)

    model_input = [quarter, mean_all_departed, route_mean, late_departure_estimate, schedule, delay_a_estimate, delay_d_estimate]
    return model_input

from PIL import Image

# Paths to your logo images
school_logo_path = '/content/drive/MyDrive/W._P._Carey_School_of_Business_logo.jpeg'
company_logo_path = '/content/drive/MyDrive/apl-logo.jpg'

# Load images using PIL
school_logo = Image.open(school_logo_path)
company_logo = Image.open(company_logo_path)

# Function to resize image while maintaining aspect ratio
def resize_image(image, target_width, target_height):
    original_width, original_height = image.size
    ratio = min(target_width/original_width, target_height/original_height)
    new_width = int(original_width * ratio)
    new_height = int(original_height * ratio)
    resized_image = image.resize((new_width, new_height), Image.ANTIALIAS)
    return resized_image

# Desired dimensions; adjust these as needed
target_width, target_height = 300, 80  # Example dimensions

# Resizing images
school_logo_resized = resize_image(school_logo, target_width, target_height)
company_logo_resized = resize_image(company_logo, target_width, target_height)

# Creating a container for the banner
banner_container = st.container()

# Use the full width of the container for each logo
with banner_container:
    col1, col2 = st.columns([1, 1])
    with col1:
        st.image(school_logo_resized, use_column_width=True)  # Use the resized logo
    with col2:
        st.image(company_logo_resized, use_column_width=True)  # Use the resized logo

# Streamlit app setup
st.markdown("<h1 style='text-align: center; color: white; font-size: 18px;'>Predicting Shipping Time/Transit Time to show ETA/ETD for shipments using GB Models</h1>", unsafe_allow_html=True)

# Use columns to split the screen into left and right
left_column, right_column = st.columns([1, 3])

# Use the left column for the first part of the app
with left_column:


                # Load your model
                model = joblib.load('/content/gradientboost_depart_new.joblib')

                # # Define your dropdown menu options
                # carrier_options = ['MAEU','YASV','DMAL','EGLV','OOLU','CMDU','EXDO','COSU','TOPO','HDMU','APLL','ONEY','YMLU','SMLU','HLCU','MEDU','OOCO','CHON','OCHK','CHRB','MSCU','YMPR','DMLB']
                # original_port_options = ['CNSHA','GTPBR','KHPNH','CNNGB','CNXMN','CNFOC','CNTAO','CNHMN','INNSA','IDSRG','CNTXG','IDJKT','IDSUB','BDCGP','CNYTN','ILHFA','TRIZM','THLCH','VNHPH','CNXIP','PKBQM','TWKHH','PECLL','HNPCR','INMUN','VNVUT','INTUT','CNDCB','CNDLC','TWTPE','5_CNDAL','CNFZH','VNSGN','CNDAL','VNDAD','DOHAI','DOCAU','VNCMT','TRALI','PKKHI','KHKOS','KHSHV','GTSTC','CNNBO','HKHKG','CNPHU','NIMGA','VNTOT','KRPUS']
                # final_port_options = ['USSEA','USORF','USLGB','USNYC','USSAV','NLRTM','USLAX','USPDX','USCHS','USTIW','USHOU','CAPRR','USMIA','USOAK','USEWR','CAVAN','CAHAL','USATL','BEANR','USCHI','CNNGB','USXMX','USPIT']
                # destination_location_options = ['US','NL','CA','BE','CN']

                # # Dropdown menus for inputs
                # carrier = st.selectbox('Carrier', carrier_options)
                # original_port_of_loading = st.selectbox('Original Port of Loading', original_port_options)
                # final_port_of_discharge = st.selectbox('Final Port of Discharge', final_port_options)
                # destination_location = st.selectbox('Destination Location', destination_location_options)

                #autofiltering enabled for port of discharge now
                original_port_options = new_df['PORT_OF_LOAD'].unique()
                destination_location_options = ['US','NL','CA','BE','CN']

                carrier = st.selectbox('Carrier', new_df['CARRIER'].unique())
                original_port_of_loading = st.selectbox('Original Port of Loading', original_port_options)
                filtered_ports = new_df[new_df['PORT_OF_LOAD'] == original_port_of_loading]['PORT_OF_DISCHARGE'].unique()
                final_port_of_discharge = st.selectbox('Final Port of Discharge', filtered_ports)
                destination_location = st.selectbox('Destination Location', destination_location_options)

                # Date input for ETA and ETD
                eta = st.date_input('Scheduled Time of Arrival')
                etd = st.date_input('Scheduled Time of Departure')
                etd = pd.to_datetime(etd)

# Use the right column for the map visualization part
with right_column:
    # Assuming we have set original_port_coords and final_port_coords based on the prediction step
    original_port_coords = get_port_coords(original_port_of_loading)
    final_port_coords = get_port_coords(final_port_of_discharge)

    # Define a pydeck layer to display the line with these dynamic coordinates
    routes = pdk.Layer(
        'LineLayer',
        data=[{
            'source': original_port_coords,
            'target': final_port_coords,
        }],
        get_source_position='source',
        get_target_position='target',
        get_color=[255, 0, 0],
        get_width=2,
        pickable=True,
    )

    # Set the view state for the map dynamically based on the selected ports
    view_state = pdk.ViewState(
        latitude=np.mean([original_port_coords[1], final_port_coords[1]]),  # Centered latitude for both ports
        longitude=np.mean([original_port_coords[0], final_port_coords[0]]),  # Centered longitude for both ports
        zoom=1,
    )

    # Render the deck in Streamlit in the right column
    r = pdk.Deck(
        layers=[routes],
        initial_view_state=view_state
    )

    st.pydeck_chart(r)

# Define the percentage mapping for each scenario including a 'None' option for zero impact
percentages = {
    'Red Sea Disruption': {'None': '0%', 'Low': '5%', 'Medium': '20%', 'High': '40%'},
    'COVID Distruption': {'None': '0%', 'Low': '10%', 'Medium': '30%', 'High': '60%'},
    'Port Congestion': {'None': '0%', 'Low': '15%', 'Medium': '35%', 'High': '55%'},
    'Weather Condition': {'None': '0%', 'Low': '5%', 'Medium': '20%', 'High': '40%'},
    'War/Terrorism': {'None': '0%', 'Low': '10%', 'Medium': '30%', 'High': '60%'},
    'Labour Strikes': {'None': '0%', 'Low': '15%', 'Medium': '35%', 'High': '55%'},
    'Custom Disruption': {'None': '0%', 'Low': '15%', 'Medium': '35%', 'High': '55%'}
}

# Setup sliders for each scenario
impact_levels = {}
for scenario, options in percentages.items():
    # Create an option label mapping for the slider
    options_with_labels = {key: f"{key} ({val})" for key, val in options.items()}
    selected_option = st.select_slider(
        label=scenario,
        options=list(options_with_labels.values()),  # Display 'None (0%)', 'Low (5%)', 'Medium (20%)', etc.
        value=options_with_labels['None'] #Default value to 'None (0%)
    )
    # Reverse lookup to get the key from the label for percentage extraction
    impact_levels[scenario] = next(key for key, value in options_with_labels.items() if value == selected_option)

# Button to predict
if st.button('Predict'):
    # Assuming placeholder functions and variables for model inputs and predictions
    model_input = prepare_model_input(carrier, original_port_of_loading, final_port_of_discharge, eta, etd)
    predicted_transit_time_days = model.predict([model_input])[0]

    # Calculate total impact percentage
    total_impact_percentage = sum(float(percentages[scenario][impact_levels[scenario]].strip('%')) for scenario in impact_levels)
    impact_multiplier = (100 + total_impact_percentage) / 100
    adjusted_transit_time_days = round(predicted_transit_time_days * impact_multiplier)

    # Calculating the predicted arrival date
    predicted_arrival_date = etd + timedelta(days=int(adjusted_transit_time_days))
    st.write(f'Predicted Arrival Date: {predicted_arrival_date.strftime("%Y-%m-%d")}')
# Out:
# Writing app.py

# %%
# !streamlit run app.py &>/content/logs.txt & npx localtunnel --port 8501 & wget -q -O - ipv4.icanhazip.com
# Out:
# 34.145.199.146
# npx: installed 22 in 6.884s
# your url is: https://cuddly-flowers-sort.loca.lt

# %%
# # Define the percentage mapping for each scenario
# percentages = {
#     'Red Sea disruption': {'Low': '5%', 'Medium': '20%', 'High': '40%'},
#     'COVID scenario': {'Low': '10%', 'Medium': '30%', 'High': '60%'},
#     'Port congestion': {'Low': '15%', 'Medium': '35%', 'High': '55%'},
#     'Weather Condition': {'Low': '5%', 'Medium': '20%', 'High': '40%'},
#     'War/Terrorism': {'Low': '10%', 'Medium': '30%', 'High': '60%'},
#     'Labour Strikes': {'Low': '15%', 'Medium': '35%', 'High': '55%'}
# }
# impact_levels = {}
# for scenario, options in percentages.items():
#     options_with_percents = {key: f"{key} ({val})" for key, val in options.items()}
#     selected_option = st.select_slider(
#         scenario,
#         options=list(options_with_percents.values()),  # Display 'Low (5%)', 'Medium (20%)', etc.
#         value=options_with_percents['Low']  # Default display value
#     )
#     # Reverse lookup to get the key from the value for percentage extraction
#     key_for_percent = next(key for key, value in options_with_percents.items() if value == selected_option)
#     impact_levels[scenario] = options[key_for_percent]


# # Create sliders for each scenario and collect the selected options
# # impact_levels = {}
# # for scenario, options in percentages.items():
# #     impact_levels[scenario] = st.select_slider(
# #         scenario,
# #         options=['Low', 'Medium', 'High'],
# #         value='Low'  # Default value
# #     )

# # When a button is pressed to predict
# if st.button('Predict'):
#     # Preparing model input as before
#     model_input = prepare_model_input(carrier, original_port_of_loading, final_port_of_discharge, eta, etd)

#     # Getting the prediction from the model. Assuming the model predicts transit time in days
#     predicted_transit_time_days = model.predict([model_input])[0]  # Assuming the output is a single value array

#     # Initialize a multiplier for the predicted transit time based on the selected impact levels
#     total_impact_percentage = 0

#     # # Sum the percentages of the selected impact levels
#     # for scenario, level in impact_levels.items():
#     #   percentage_value = float(percentages[scenario][level].replace('%', ''))
#     #   total_impact_percentage += percentage_value
#     total_impact_percentage = sum(float(impact_levels[scenario].replace('%', '')) for scenario in impact_levels)
#     # Calculate the adjusted transit time by adding the impact percentage
#     impact_multiplier = (100 + total_impact_percentage) / 100
#     adjusted_transit_time_days = predicted_transit_time_days * impact_multiplier


#     # Calculating the predicted arrival date by adding the transit time to ETD
#     predicted_arrival_date = etd + timedelta(days=adjusted_transit_time_days)

#     # Display the prediction
#     st.write(f'Predicted Arrival Date: {predicted_arrival_date.strftime("%Y-%m-%d")}')

# %%
# %%writefile app1.py
# import streamlit as st
# import pandas as pd
# import numpy as np
# import joblib
# from datetime import datetime, timedelta
# import pydeck as pdk
# from PIL import Image

# # Load the dataset with port coordinates
# ports_coords = pd.read_excel('/content/drive/MyDrive/port_coordinates.xlsx')

# # Function to get coordinates by port code
# def get_port_coords(port_code):
#     row = ports_coords[ports_coords['Port Code'] == port_code].iloc[0]
#     return [row['Longitude'], row['Latitude']]

# # Load precomputed data
# chinese_holidays = pd.read_csv('/content/drive/MyDrive/chinese_holidays_complete.csv', sep=',', encoding='utf-8')
# chinese_holidays['date'] = pd.to_datetime(chinese_holidays['date'])
# new_df = pd.read_csv('/content/drive/MyDrive/new_df.csv')

# # Load images using PIL
# school_logo_path = '/content/drive/MyDrive/W._P._Carey_School_of_Business_logo.jpeg'
# company_logo_path = '/content/drive/MyDrive/APLL_logo.jpg'
# school_logo = Image.open(school_logo_path)
# company_logo = Image.open(company_logo_path)

# # Function to resize image
# def resize_image(image, target_width, target_height):
#     original_width, original_height = image.size
#     ratio = min(target_width/original_width, target_height/original_height)
#     new_width = int(original_width * ratio)
#     new_height = int(original_height * ratio)
#     resized_image = image.resize((new_width, new_height), Image.ANTIALIAS)
#     return resized_image

# # Resizing images
# target_width, target_height = 300, 80
# school_logo_resized = resize_image(school_logo, target_width, target_height)
# company_logo_resized = resize_image(company_logo, target_width, target_height)

# # Streamlit app setup
# st.markdown("<h1 style='text-align: center; color: white; font-size: 18px;'>Predicting Shipping Time/Transit Time to show ETA/ETD for shipments using ML Models</h1>", unsafe_allow_html=True)
# banner_container = st.container()
# with banner_container:
#     col1, col2 = st.columns([1, 1])
#     with col1:
#         st.image(school_logo_resized, use_column_width=True)
#     with col2:
#         st.image(company_logo_resized, use_column_width=True)

# left_column, right_column = st.columns([1, 3])

# with left_column:
#     model = joblib.load('/content/gradientboost_depart_new.joblib')
#     original_port_options = new_df['PORT_OF_LOAD'].unique()
#     destination_location_options = ['US','NL','CA','BE','CN']

#     carrier = st.selectbox('Carrier', new_df['CARRIER'].unique())
#     original_port_of_loading = st.selectbox('Original Port of Loading', original_port_options)
#     filtered_ports = new_df[new_df['PORT_OF_LOAD'] == original_port_of_loading]['PORT_OF_DISCHARGE'].unique()
#     final_port_of_discharge = st.selectbox('Final Port of Discharge', filtered_ports)
#     destination_location = st.selectbox('Destination Location', destination_location_options)
#     eta = st.date_input('Scheduled Time of Arrival')
#     etd = st.date_input('Scheduled Time of Departure')
#     etd = pd.to_datetime(etd)

#     if st.button('Predict'):
#         model_input = [carrier, original_port_of_loading, final_port_of_discharge, eta, etd]
#         predicted_transit_time_days = model.predict([model_input])[0]
#         predicted_arrival_date = etd + timedelta(days=predicted_transit_time_days)
#         st.write(f'Predicted Arrival Date: {predicted_arrival_date.strftime("%Y-%m-%d")}')

# with right_column:
#     original_port_coords = get_port_coords(original_port_of_loading)
#     final_port_coords = get_port_coords(final_port_of_discharge)
#     routes = pdk.Layer(
#         'LineLayer',
#         data=[{'source': original_port_coords, 'target': final_port_coords}],
#         get_source_position='source',
#         get_target_position='target',
#         get_color=[255, 0, 0],
#         get_width=2,
#         pickable=True,
#     )
#     view_state = pdk.ViewState(
#         latitude=np.mean([original_port_coords[1], final_port_coords[1]]),
#         longitude=np.mean([original_port_coords[0], final_port_coords[0]]),
#         zoom=1,
#     )
#     r = pdk.Deck(
#         layers=[routes],
#         initial_view_state=view_state
#     )
#     st.pydeck_chart(r)
# Out:
# Overwriting app1.py

# %%
# !streamlit run app1.py &>/content/logs.txt & npx localtunnel --port 8501 & wget -q -O - ipv4.icanhazip.com
# Out:
# 34.106.102.180
# npx: installed 22 in 2.998s
# your url is: https://new-olives-look.loca.lt
